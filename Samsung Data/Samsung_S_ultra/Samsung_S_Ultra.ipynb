# %%
import re
import pandas as pd

s22ultra = pd.read_csv('galaxy_s22_ultra_only.csv')

# Step 1: Remove rows with '|' (multiple model options)
s22ultra = s22ultra[~s22ultra['Title'].str.contains(r'\|', regex=True, na=False)]

# Step 2: Remove titles that list multiple models like "S22 / S22+" or "S22 - S22 Ultra"
pattern_multi = r'\bS?22\b\s*[-/|]\s*\bS?22\s*(?:Ultra|\+|Plus)?\b'
s22ultra = s22ultra[~s22ultra['Title'].str.contains(pattern_multi, flags=re.IGNORECASE, na=False)]

# Step 3: Keep only "Samsung Galaxy S22 Ultra"
s22ultra = s22ultra[
    s22ultra['Title'].str.contains(r'\b(Samsung\s*)?(Galaxy\s*)?S22\s*Ultra\b', flags=re.IGNORECASE, na=False)
    & ~s22ultra['Title'].str.contains(r'\bS22\s*(\+|Plus|Base|Regular)\b', flags=re.IGNORECASE, na=False)
]

# Preview the results
s22ultra
# Out:
# /var/folders/g_/07970pkx1s139mt1t4qm27080000gn/T/ipykernel_97132/2571240186.py:15: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   s22ultra['Title'].str.contains(r'\b(Samsung\s*)?(Galaxy\s*)?S22\s*Ultra\b', flags=re.IGNORECASE, na=False)
# /var/folders/g_/07970pkx1s139mt1t4qm27080000gn/T/ipykernel_97132/2571240186.py:16: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~s22ultra['Title'].str.contains(r'\bS22\s*(\+|Plus|Base|Regular)\b', flags=re.IGNORECASE, na=False)
#      Page                                              Title    Price  \
# 0       1  Samsung Galaxy S22 Ultra 128GB S908U Unlocked ...  $250.99
# 1       1  Samsung Galaxy S22 Ultra 512GB S908U Unlocked ...  $298.99
# 2       1  Samsung Galaxy S22 Ultra 512GB Unlocked ATT T-...  $376.95
# ...

# %%
import re
import pandas as pd

s23ultra = pd.read_csv('galaxy_s23_ultra_only.csv')

# Step 1: Remove rows with '|' (multiple model options)
s23ultra = s23ultra[~s23ultra['Title'].str.contains(r'\|', regex=True, na=False)]

# Step 2: Remove titles that list multiple models like "S23 / S23+" or "S23 - S23 Ultra"
pattern_multi = r'\bS?23\b\s*[-/|]\s*\bS?23\s*(?:Ultra|\+|Plus)?\b'
s23ultra = s23ultra[~s23ultra['Title'].str.contains(pattern_multi, flags=re.IGNORECASE, na=False)]

# Step 3: Keep only "Samsung Galaxy S23 Ultra"
s23ultra = s23ultra[
    s23ultra['Title'].str.contains(r'\b(Samsung\s*)?(Galaxy\s*)?S23\s*Ultra\b', flags=re.IGNORECASE, na=False)
    & ~s23ultra['Title'].str.contains(r'\bS23\s*(\+|Plus|Base|Regular)\b', flags=re.IGNORECASE, na=False)
]

# Preview the results
s23ultra
# Out:
# /var/folders/g_/07970pkx1s139mt1t4qm27080000gn/T/ipykernel_97132/167736706.py:15: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   s23ultra['Title'].str.contains(r'\b(Samsung\s*)?(Galaxy\s*)?S23\s*Ultra\b', flags=re.IGNORECASE, na=False)
# /var/folders/g_/07970pkx1s139mt1t4qm27080000gn/T/ipykernel_97132/167736706.py:16: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~s23ultra['Title'].str.contains(r'\bS23\s*(\+|Plus|Base|Regular)\b', flags=re.IGNORECASE, na=False)
#      Page                                              Title    Price  \
# 0       1  Samsung Galaxy S23 Ultra 512GB S918U Unlocked ...  $419.99
# 1       1  Samsung Galaxy S23 Ultra 256GB S918U Unlocked ...  $429.99
# 2       1  Samsung Galaxy S23 Ultra 512GB S918U Unlocked ...  $443.99
# ...

# %%
import re
import pandas as pd

# Load your dataset
s24ultra = pd.read_csv('galaxy_s24_ultra_only.csv')

# Step 1: Remove rows with '|' (multiple model options)
s24ultra = s24ultra[~s24ultra['Title'].str.contains(r'\|', regex=True, na=False)]

# Step 2: Remove titles that list multiple models like "S24 / S24+" or "S24 - S24 Ultra"
pattern_multi = r'\bS?24\b\s*[-/|]\s*\bS?24\s*(?:Ultra|\+|Plus)?\b'
s24ultra = s24ultra[~s24ultra['Title'].str.contains(pattern_multi, flags=re.IGNORECASE, na=False)]

# Step 3: Keep only "Samsung Galaxy S24 Ultra"
s24ultra = s24ultra[
    s24ultra['Title'].str.contains(r'\b(Samsung\s*)?(Galaxy\s*)?S24\s*Ultra\b', flags=re.IGNORECASE, na=False)
    & ~s24ultra['Title'].str.contains(r'\bS24\s*(\+|Plus|Base|Regular|FE)\b', flags=re.IGNORECASE, na=False)
]

# Preview the results
s24ultra
# Out:
# /var/folders/g_/07970pkx1s139mt1t4qm27080000gn/T/ipykernel_97132/4064701355.py:16: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   s24ultra['Title'].str.contains(r'\b(Samsung\s*)?(Galaxy\s*)?S24\s*Ultra\b', flags=re.IGNORECASE, na=False)
# /var/folders/g_/07970pkx1s139mt1t4qm27080000gn/T/ipykernel_97132/4064701355.py:17: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~s24ultra['Title'].str.contains(r'\bS24\s*(\+|Plus|Base|Regular|FE)\b', flags=re.IGNORECASE, na=False)
#      Page                                              Title    Price  \
# 0       1  Samsung Galaxy S24 Ultra 512GB S928U Unlocked ...  $653.99
# 1       1  Samsung Galaxy S24 Ultra 512GB Unlocked ATT T-...  $690.95
# 2       1  Samsung Galaxy S24 Ultra 512GB SM-S928U1 Gray ...  $559.00
# ...

# %%
import re
import pandas as pd

# Load your dataset
s25ultra = pd.read_csv('galaxy_s25_ultra_only.csv')

# Step 1: Remove rows with '|' (multiple model options)
s25ultra = s25ultra[~s25ultra['Title'].str.contains(r'\|', regex=True, na=False)]

# Step 2: Remove titles that list multiple models like "S25 / S25+" or "S25 - S25 Ultra"
pattern_multi = r'\bS?25\b\s*[-/|]\s*\bS?25\s*(?:Ultra|\+|Plus)?\b'
s25ultra = s25ultra[~s25ultra['Title'].str.contains(pattern_multi, flags=re.IGNORECASE, na=False)]

# Step 3: Keep only "Samsung Galaxy S25 Ultra"
s25ultra = s25ultra[
    s25ultra['Title'].str.contains(r'\b(Samsung\s*)?(Galaxy\s*)?S25\s*Ultra\b', flags=re.IGNORECASE, na=False)
    & ~s25ultra['Title'].str.contains(r'\bS25\s*(\+|Plus|Base|Regular|FE)\b', flags=re.IGNORECASE, na=False)
]

# Preview the results
s25ultra
# Out:
# /var/folders/g_/07970pkx1s139mt1t4qm27080000gn/T/ipykernel_97132/3648518757.py:16: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   s25ultra['Title'].str.contains(r'\b(Samsung\s*)?(Galaxy\s*)?S25\s*Ultra\b', flags=re.IGNORECASE, na=False)
# /var/folders/g_/07970pkx1s139mt1t4qm27080000gn/T/ipykernel_97132/3648518757.py:17: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~s25ultra['Title'].str.contains(r'\bS25\s*(\+|Plus|Base|Regular|FE)\b', flags=re.IGNORECASE, na=False)
#      Page                                              Title      Price  \
# 0       1  Samsung Galaxy S25 Ultra 256GB 512GB SM-S938U1...    $799.00
# 1       1  Samsung Galaxy S25 Ultra 256GB Titanium Jetbla...    $839.99
# 2       1  Samsung Galaxy S25 Ultra 512GB 6.9", Titanium ...    $899.99
# ...

# %%
# Combine all cleaned DataFrames
combined_ultra = pd.concat([s22ultra, s23ultra, s24ultra, s25ultra], ignore_index=True)

# Save to a new CSV
combined_ultra.to_csv('Samsung_Series_Ultra_Combined.csv', index=False)

# %%
import pandas as pd

data = pd.read_csv('Samsung_Series_Ultra_Combined.csv')

# Normalize both columns
data['Condition'] = data['Condition'].astype(str).str.strip()
data['Storage']   = data['Storage'].astype(str).str.strip()

# Remove any rows where Condition OR Storage contains "unk" in any form
mask = ~data['Condition'].str.contains(r'unk', case=False, na=False) & \
       ~data['Storage'].str.contains(r'unk', case=False, na=False)

data = data[mask]
data
# Out:
#       Page                                              Title    Price  \
# 0        1  Samsung Galaxy S22 Ultra 128GB S908U Unlocked ...  $250.99
# 1        1  Samsung Galaxy S22 Ultra 512GB S908U Unlocked ...  $298.99
# 2        1  Samsung Galaxy S22 Ultra 512GB Unlocked ATT T-...  $376.95
# 3        1  Samsung Galaxy S22 Ultra 512GB S908U Unlocked ...  $325.99
# 4        1  Samsung Galaxy S22 Ultra SM-S908U1 Unlocked 12...  $269.99
# ...    ...                                                ...      ...
# 1041     1  Samsung Galaxy S25 Ultra 512GB Titanium Jadegr...  $849.99
# 1042     1  Samsung Galaxy S25 Ultra - Unlocked - Titanium...  $835.00
# 1043     1  Samsung Galaxy S25 Ultra 512GB Unlocked Titani...  $879.95
# 1044     1  Samsung Galaxy S25 Ultra - Unlocked - Titanium...  $839.00
# 1050     1  Samsung Galaxy S25 Ultra SM-S938U Unlocked 256...  $901.79
#
#        Sold Date                                   Link  \
# 0     2025-10-29  https://www.ebay.com/itm/256412927142
# ...

# %%
data['Sold Date'] = pd.to_datetime(data['Sold Date'])
data['year']= data['Sold Date'].dt.year
data['Month'] = data['Sold Date'].dt.month
data['Price_num'] = data['Price'].str.replace('$', '').str.replace(',', '').astype(float)
data
# Out:
#       Page                                              Title    Price  \
# 0        1  Samsung Galaxy S22 Ultra 128GB S908U Unlocked ...  $250.99
# 1        1  Samsung Galaxy S22 Ultra 512GB S908U Unlocked ...  $298.99
# 2        1  Samsung Galaxy S22 Ultra 512GB Unlocked ATT T-...  $376.95
# 3        1  Samsung Galaxy S22 Ultra 512GB S908U Unlocked ...  $325.99
# 4        1  Samsung Galaxy S22 Ultra SM-S908U1 Unlocked 12...  $269.99
# ...    ...                                                ...      ...
# 1041     1  Samsung Galaxy S25 Ultra 512GB Titanium Jadegr...  $849.99
# 1042     1  Samsung Galaxy S25 Ultra - Unlocked - Titanium...  $835.00
# 1043     1  Samsung Galaxy S25 Ultra 512GB Unlocked Titani...  $879.95
# 1044     1  Samsung Galaxy S25 Ultra - Unlocked - Titanium...  $839.00
# 1050     1  Samsung Galaxy S25 Ultra SM-S938U Unlocked 256...  $901.79
#
#       Sold Date                                   Link  \
# 0    2025-10-29  https://www.ebay.com/itm/256412927142
# ...

# %%
import pandas as pd

# --- RELEASE DATE MAPPING FOR ULTRA SERIES ---

data['Release Date'] = data['Model'].replace({
    "Galaxy S22 Ultra": "2022-02",
    "Galaxy S23 Ultra": "2023-02",
    "Galaxy S24 Ultra": "2024-01",
    "Galaxy S25 Ultra": "2025-01",   # adjust if needed
})

# Convert to datetime
data['Release Date'] = pd.to_datetime(data['Release Date'], errors='coerce')

# --- COMPUTE AGE IN MONTHS ---
data["Age_at_Sale"] = (
    (data['Sold Date'] - data['Release Date']).dt.days / 30.44
).round(2)

data
# Out:
#       Page                                              Title    Price  \
# 0        1  Samsung Galaxy S22 Ultra 128GB S908U Unlocked ...  $250.99
# 1        1  Samsung Galaxy S22 Ultra 512GB S908U Unlocked ...  $298.99
# 2        1  Samsung Galaxy S22 Ultra 512GB Unlocked ATT T-...  $376.95
# 3        1  Samsung Galaxy S22 Ultra 512GB S908U Unlocked ...  $325.99
# 4        1  Samsung Galaxy S22 Ultra SM-S908U1 Unlocked 12...  $269.99
# ...    ...                                                ...      ...
# 1041     1  Samsung Galaxy S25 Ultra 512GB Titanium Jadegr...  $849.99
# 1042     1  Samsung Galaxy S25 Ultra - Unlocked - Titanium...  $835.00
# 1043     1  Samsung Galaxy S25 Ultra 512GB Unlocked Titani...  $879.95
# 1044     1  Samsung Galaxy S25 Ultra - Unlocked - Titanium...  $839.00
# 1050     1  Samsung Galaxy S25 Ultra SM-S938U Unlocked 256...  $901.79
#
#       Sold Date                                   Link  \
# 0    2025-10-29  https://www.ebay.com/itm/256412927142
# ...

# %%
import re
import numpy as np
import pandas as pd

# --- Samsung Galaxy S Ultra launch prices (US MSRP, S22 Ultra–S25 Ultra) ---

samsung_ultra_release_price_map = {
    # Galaxy S22 Ultra
    'Galaxy S22 Ultra': {
        '128': 1199.0,
        '256': 1299.0,
        '512': 1399.0,
        '1024': 1599.0,   # 1TB
    },

    # Galaxy S23 Ultra (no 128GB base)
    'Galaxy S23 Ultra': {
        '256': 1199.0,
        '512': 1379.0,
        '1024': 1619.0,
    },

    # Galaxy S24 Ultra
    'Galaxy S24 Ultra': {
        '256': 1299.0,
        '512': 1419.0,
        '1024': 1659.0,
    },

    # Galaxy S25 Ultra (assumed same as S24 Ultra for now)
    'Galaxy S25 Ultra': {
        '256': 1299.0,
        '512': 1419.0,
        '1024': 1659.0,
    },
}

# --- Storage extractor (same idea as your Plus code) ---

def extract_storage_from_row(row):
    # Try common explicit columns first (if they exist)
    for col in ['Storage', 'Capacity', 'Memory', 'Storage Capacity']:
        if col in row.index and pd.notna(row[col]):
            s = str(row[col])
            m = re.search(r'(64|128|256|512|1024)', s)
            if m:
                return m.group(1)

    # Fallback: parse Model + Title
    text = f"{row.get('Model', '')} {row.get('Title', '')}"
    m = re.search(
        r'\b(64|128|256|512|1024)\s*(?:GB|G|gb|Tb|TB)?\b',
        text,
        flags=re.IGNORECASE
    )
    if m:
        return m.group(1)

    return None

# --- Super-simple model key extractor: exact "Galaxy Sxx Ultra" ---

def extract_samsung_ultra_model_key(row):
    model = str(row.get('Model', '')).strip()

    # If your Model is exactly "Galaxy S22 Ultra" etc:
    for key in samsung_ultra_release_price_map.keys():
        if model.startswith(key):
            return key

    # Optional: also look in Title if needed
    title = str(row.get('Title', '')).strip()
    for key in samsung_ultra_release_price_map.keys():
        if key in title:
            return key

    return None

# --- Mapper to assign first-release price for Samsung Galaxy S Ultra series ---

def map_samsung_ultra_first_release_price(row):
    model_key = extract_samsung_ultra_model_key(row)   # e.g. "Galaxy S23 Ultra"
    if not model_key:
        return np.nan

    storage = extract_storage_from_row(row)
    if not storage:
        return np.nan

    price_map = samsung_ultra_release_price_map.get(model_key, {})
    return price_map.get(storage, np.nan)

# --- Load data if needed ---

if 'data' not in globals():
    try:
        data = pd.read_csv('Samsung_Series_Ultra_Combined.csv')  # change if needed
        if 'Sold Date' in data.columns:
            data['Sold Date'] = pd.to_datetime(data['Sold Date'], errors='coerce')
    except FileNotFoundError:
        raise FileNotFoundError('Samsung_Series_Ultra_Combined.csv not found; load your Samsung Ultra data into `data`')

# Create/overwrite the column with Samsung Ultra launch prices
data['First_Release_Price'] = data.apply(map_samsung_ultra_first_release_price, axis=1)

# --- Simple sanity check: count non-NaN prices per Ultra model string ---

for key in samsung_ultra_release_price_map.keys():
    mask = data['Model'].astype(str).str.startswith(key, na=False)
    total = data[mask].shape[0]
    filled = data[mask & data['First_Release_Price'].notna()].shape[0]
    print(f'{key}: filled {filled} / {total}')

# Show sample rows where price was set
display(data[data['First_Release_Price'].notna()].head())
# Out:
# Galaxy S22 Ultra: filled 149 / 149
# Galaxy S23 Ultra: filled 93 / 93
# Galaxy S24 Ultra: filled 102 / 108
# Galaxy S25 Ultra: filled 65 / 65
#    Page                                              Title    Price  \
# 0     1  Samsung Galaxy S22 Ultra 128GB S908U Unlocked ...  $250.99
# 1     1  Samsung Galaxy S22 Ultra 512GB S908U Unlocked ...  $298.99
# 2     1  Samsung Galaxy S22 Ultra 512GB Unlocked ATT T-...  $376.95
# 3     1  Samsung Galaxy S22 Ultra 512GB S908U Unlocked ...  $325.99
# 4     1  Samsung Galaxy S22 Ultra SM-S908U1 Unlocked 12...  $269.99
#
#    Sold Date                                   Link  \
# 0 2025-10-29  https://www.ebay.com/itm/256412927142
# 1 2025-10-29  https://www.ebay.com/itm/256497629590
# 2 2025-10-29  https://www.ebay.com/itm/306175185652
# 3 2025-10-29  https://www.ebay.com/itm/256483219243
# 4 2025-10-28  https://www.ebay.com/itm/176490035899
#
#                                           Image Link Storage  Condition  \
# ...

# %%
from matplotlib import pyplot as plt
import numpy as np

# Make sure column names are clean
data.rename(columns=str.strip, inplace=True)

# Use clean columns
x = data['Age_at_Sale']          # months
y = data['Price_num']            # resale price in $

# Drop NaNs/infs before fitting
m = np.isfinite(x) & np.isfinite(y)
x = x[m].to_numpy()
y = y[m].to_numpy()

# Fit and build 3rd-degree polynomial
degree = 3
coeffs = np.polyfit(x, y, degree)
poly_eq = np.poly1d(coeffs)

# Smooth curve for the fit
x_line = np.linspace(x.min(), x.max(), 200)
y_line = poly_eq(x_line)

# Plot scatter + fitted curve
plt.scatter(x, y, s=15, alpha=0.6, label='Galaxy S22 Ultra–S25 Ultra Data')
plt.plot(x_line, y_line, linewidth=2, label=f'{degree}rd-degree fit')
plt.xlabel('Age at Sale (Months)')
plt.ylabel('Price ($)')
plt.title('Galaxy S22 Ultra–S25 Ultra Price Depreciation Over Time (3rd-degree Polynomial)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

# Make sure column names are clean
data.rename(columns=str.strip, inplace=True)

# Use clean columns
x = data['Age_at_Sale']          # months
y = data['Price_num']            # resale price in $

# Drop NaNs/infs before fitting
m = np.isfinite(x) & np.isfinite(y)
x = x[m].to_numpy()
y = y[m].to_numpy()

# -------------------------------
# Convert price → retention value
# -------------------------------
original_price = y.max()
retention = (y / original_price) * 100.0

# Fit and build 3rd-degree polynomial
degree = 3
coeffs = np.polyfit(x, retention, degree)
poly_eq = np.poly1d(coeffs)

# Smooth line
x_line = np.linspace(x.min(), x.max(), 200)
y_line = poly_eq(x_line)

# -------------------------------
# Plot
# -------------------------------
plt.scatter(x, retention, s=15, alpha=0.6, label='Samsung Galaxy S Ultra Data')
plt.plot(x_line, y_line, linewidth=2, label=f'{degree}rd-degree retention fit')

plt.xlabel('Age at Sale (Months)')
plt.ylabel('Value Retained (%)')
plt.title('Samsung Galaxy S Ultra Value Retention Over Time')
plt.ylim(0, 110)

# ⭐ Fix legend in the top-right corner
plt.legend(loc='upper right')


import os
# Save figure
os.makedirs('output', exist_ok=True)
plt.savefig('output/samsung_s_ultra_value_retention_polynomial_fit.png', dpi=300)

plt.tight_layout()
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
import os

# --- YOUR EXISTING SETUP ---
# Make sure column names are clean
data.rename(columns=str.strip, inplace=True)

# Use clean columns
x = data['Age_at_Sale']          # months
y = data['Price_num']            # resale price in $

# Drop NaNs/infs before fitting
m = np.isfinite(x) & np.isfinite(y)
x = x[m].to_numpy()
y = y[m].to_numpy()

# -------------------------------
# Convert price -> retention value
# -------------------------------
# NOTE: Ensure y.max() is actually the original MSRP. 
# If you have a specific launch price (e.g., $1199), replace y.max() with 1199.
original_price = y.max() 
retention = (y / original_price) * 100.0

# Fit and build 3rd-degree polynomial
degree = 3
coeffs = np.polyfit(x, retention, degree)
poly_eq = np.poly1d(coeffs)

# Smooth line for plotting
x_line = np.linspace(x.min(), x.max(), 200)
y_line = poly_eq(x_line)

# -------------------------------
# ⭐ NEW: Get Table Values
# -------------------------------
val_12 = poly_eq(12)
val_24 = poly_eq(24)

print("-" * 30)
print("TABLE VALUES FOR THIS PHONE:")
print(f"12 Months: {val_12:.2f}%")
print(f"24 Months: {val_24:.2f}%")
print("-" * 30)

# -------------------------------
# Plotting (Same as before)
# -------------------------------
plt.scatter(x, retention, s=15, alpha=0.6, label='Samsung Galaxy S Ultra Data')
plt.plot(x_line, y_line, linewidth=2, label=f'{degree}rd-degree retention fit')

plt.xlabel('Age at Sale (Months)')
plt.ylabel('Value Retained (%)')
plt.title('Samsung Galaxy S Ultra Value Retention Over Time')
plt.ylim(0, 110)
plt.legend(loc='upper right')

os.makedirs('output', exist_ok=True)
plt.savefig('output/samsung_s_ultra_value_retention_polynomial_fit.png', dpi=300)

plt.tight_layout()
plt.show()
# Out:
# ------------------------------
# TABLE VALUES FOR THIS PHONE:
# 12 Months: 80.76%
# 24 Months: 59.32%
# ------------------------------

# %%
from matplotlib import pyplot as plt
import numpy as np
import os

# [Ensure your 'data' DataFrame is loaded before this point]

# Make sure column names are clean
data.rename(columns=str.strip, inplace=True)

# Use clean columns
x = data['Age_at_Sale']          # months
y = data['Price_num']            # resale price in $

# Drop NaNs/infs before fitting
m = np.isfinite(x) & np.isfinite(y)
x = x[m].to_numpy()
y = y[m].to_numpy()

# -------------------------------
# Convert price -> retention value
# -------------------------------
# NOTE: Ensure y.max() is actually the original MSRP. 
# If you have a specific launch price (e.g., $1199), replace y.max() with 1199.
original_price = y.max() 
retention = (y / original_price) * 100.0

# Fit and build 3rd-degree polynomial
degree = 3
coeffs = np.polyfit(x, retention, degree)
poly_eq = np.poly1d(coeffs)

# Smooth line for plotting
# Ensure the line extends to at least 48 months for the visual
x_max_plot = max(x.max(), 48)
x_line = np.linspace(x.min(), x_max_plot, 200)
y_line = poly_eq(x_line)

# -------------------------------
# ⭐ NEW: Get Table Values
# -------------------------------
months_to_check = [3, 6, 12, 18, 24, 48]
rmse_val = 0.029393355780788073  # User provided RMSE

print("-" * 40)
print("TABLE VALUES FOR SAMSUNG S ULTRA:")
for month in months_to_check:
    val = poly_eq(month)
    print(f"{month} Months: {val:.2f}%")
print("-" * 40)
print(f"Model RMSE: {rmse_val}")
print("-" * 40)

# -------------------------------
# Plotting
# -------------------------------
plt.figure(figsize=(10, 6))
plt.scatter(x, retention, s=15, alpha=0.6, label='Samsung Galaxy S Ultra Data')
plt.plot(x_line, y_line, linewidth=2, color='tab:orange', 
         label=f'{degree}rd-degree retention fit')

# Optional: Add markers for the specific months requested
for month in months_to_check:
    val = poly_eq(month)
    if x.min() <= month <= x_max_plot:
        plt.plot(month, val, 'ro', markersize=5)

# ⭐ Add RMSE Text Box to the plot
textstr = f'RMSE: {rmse_val:.5f}'
props = dict(boxstyle='round', facecolor='white', alpha=0.5)
plt.text(0.02, 0.05, textstr, transform=plt.gca().transAxes, fontsize=10,
        verticalalignment='bottom', bbox=props)

plt.xlabel('Age at Sale (Months)')
plt.ylabel('Value Retained (%)')
plt.title('Samsung Galaxy S Ultra Value Retention Over Time')
plt.ylim(0, 110)
plt.legend(loc='upper right')
plt.tight_layout()

os.makedirs('output', exist_ok=True)
plt.savefig('output/samsung_s_ultra_value_retention_polynomial_fit.png', dpi=300)

plt.show()
# Out:
# ----------------------------------------
# TABLE VALUES FOR SAMSUNG S ULTRA:
# 3 Months: 91.50%
# 6 Months: 88.76%
# 12 Months: 80.76%
# 18 Months: 70.52%
# 24 Months: 59.32%
# 48 Months: 30.96%
# ----------------------------------------
# Model RMSE: 0.029393355780788073
# ----------------------------------------

# %%
from matplotlib import pyplot as plt
import numpy as np
import os

# [Ensure your 'data' DataFrame is loaded before this point]
# Example: data = df[df['Variant'] == 'Galaxy S Ultra'].copy()

# Make sure column names are clean
data.rename(columns=str.strip, inplace=True)

# Use clean columns
x = data['Age_at_Sale']          # months
y = data['Price_num']            # resale price in $

# Drop NaNs/infs before fitting
m = np.isfinite(x) & np.isfinite(y)
x = x[m].to_numpy()
y = y[m].to_numpy()

# -------------------------------
# Convert price -> retention value
# -------------------------------
# NOTE: Ensure y.max() is actually the original MSRP. 
original_price = y.max() 
retention = (y / original_price) * 100.0

# Fit and build 3rd-degree polynomial
degree = 3
coeffs = np.polyfit(x, retention, degree)
poly_eq = np.poly1d(coeffs)

# Smooth line for plotting
# Ensure the line extends to at least 48 months for the visual
x_max_plot = max(x.max(), 48)
x_line = np.linspace(x.min(), x_max_plot, 200)
y_line = poly_eq(x_line)

# -------------------------------
# ⭐ NEW: Get Table Values (Added 30 Months)
# -------------------------------
# Added 30 to this list
months_to_check = [3, 6, 12, 18, 24, 30, 48] 
rmse_val = 0.029393355780788073  # User provided RMSE

print("-" * 40)
print("TABLE VALUES FOR THIS VARIANT:")
for month in months_to_check:
    val = poly_eq(month)
    print(f"{month} Months: {val:.2f}%")
print("-" * 40)
print(f"Model RMSE: {rmse_val}")
print("-" * 40)

# -------------------------------
# Plotting
# -------------------------------
plt.figure(figsize=(10, 6))
plt.scatter(x, retention, s=15, alpha=0.6, label='Observed Data')
plt.plot(x_line, y_line, linewidth=2, color='tab:orange', 
         label=f'{degree}rd-degree retention fit')

# Optional: Add markers for the specific months requested
for month in months_to_check:
    val = poly_eq(month)
    # Only plot marker if it fits within the plot range
    if x.min() <= month <= x_max_plot:
        plt.plot(month, val, 'ro', markersize=5)

# ⭐ Add RMSE Text Box
textstr = f'RMSE: {rmse_val:.5f}'
props = dict(boxstyle='round', facecolor='white', alpha=0.5)
plt.text(0.02, 0.05, textstr, transform=plt.gca().transAxes, fontsize=10,
        verticalalignment='bottom', bbox=props)

plt.xlabel('Age at Sale (Months)')
plt.ylabel('Value Retained (%)')
plt.title('Value Retention Over Time (Polynomial Fit)')
plt.ylim(0, 110)
plt.legend(loc='upper right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

os.makedirs('output', exist_ok=True)
plt.savefig('output/value_retention_polynomial_fit.png', dpi=300)

plt.show()
# Out:
# ----------------------------------------
# TABLE VALUES FOR THIS VARIANT:
# 3 Months: 89.60%
# 6 Months: 87.38%
# 12 Months: 80.15%
# 18 Months: 70.34%
# 24 Months: 59.33%
# 30 Months: 48.52%
# 48 Months: 31.02%
# ----------------------------------------
# Model RMSE: 0.029393355780788073
# ----------------------------------------

# %%
# === Samsung S Ultra resale regression (Galaxy S22 Ultra–S25 Ultra) ===

import re
import numpy as np
import pandas as pd
import sklearn.linear_model as lm
from sklearn.preprocessing import OneHotEncoder

# ------------------------------------------------------------
# 1) LOAD / PREP SAMSUNG ULTRA DATA
# ------------------------------------------------------------

# If `data` not already defined, load from CSV
if 'data' not in globals():
    data = pd.read_csv('Samsung_Series_Ultra_Combined.csv')  # <-- change filename if needed

# Clean column names and dates
data = data.rename(columns=str.strip).copy()
data['Sold Date'] = pd.to_datetime(data['Sold Date'], errors='coerce')

# Numeric sold price
data['Price_num'] = (
    data['Price']
        .astype(str)
        .str.replace('$', '', regex=False)
        .str.replace(',', '', regex=False)
        .astype(float)
)

# ------------------------------------------------------------
# 2) RELEASE MONTHS FOR S22 Ultra–S25 Ultra
# ------------------------------------------------------------
release_month_map_ultra = {
    '22': "2022-02",  # S22 Ultra Feb 2022
    '23': "2023-02",  # S23 Ultra Feb 2023
    '24': "2024-01",  # S24 Ultra Jan 2024
    '25': "2025-02",  # S25 Ultra early 2025 (assumed)
}

def extract_samsung_ultra_model_number(row):
    """
    Extract S number (22, 23, 24, 25) for ULTRA models like:
      'Galaxy S22 Ultra'
      'Samsung Galaxy S23 Ultra 256GB'
    """
    text = str(row.get('Model', '') or row.get('Title', ''))
    m = re.search(
        r'galaxy\s*s\s*(22|23|24|25)\s*ultra\b',
        text,
        flags=re.IGNORECASE
    )
    if m:
        return m.group(1)  # '22', '23', '24', '25'
    return None

def map_release_month_ultra(row):
    model_num = extract_samsung_ultra_model_number(row)
    if not model_num:
        return np.nan
    return release_month_map_ultra.get(model_num.strip(), np.nan)

data['Release Date'] = data.apply(map_release_month_ultra, axis=1)
data['Release Date'] = pd.to_datetime(data['Release Date'], errors='coerce')

# ------------------------------------------------------------
# 3) Samsung Ultra Launch Prices (US MSRP)
# ------------------------------------------------------------
# Adjust these if you have an exact launch price table
samsung_ultra_launch_price = {
    # S22 Ultra : 128/256/512/1TB
    '22': { '128': 1199.0, '256': 1299.0, '512': 1399.0, '1024': 1599.0 },

    # S23 Ultra : base 256GB, no 128GB
    '23': { '256': 1199.0, '512': 1379.0, '1024': 1619.0 },

    # S24 Ultra
    '24': { '256': 1299.0, '512': 1419.0, '1024': 1659.0 },

    # S25 Ultra : assume same tiers as S24 Ultra
    '25': { '256': 1299.0, '512': 1419.0, '1024': 1659.0 },
}

def extract_storage(row):
    """Extract storage (GB) from Storage, Model, Title."""
    # direct columns first
    for col in ['Storage', 'Capacity', 'Memory', 'Storage Capacity']:
        if col in row.index and pd.notna(row[col]):
            m = re.search(r'(128|256|512|1024)', str(row[col]))
            if m:
                return m.group(1)

    # fallback: parse from full text
    text = str(row.get('Model', '')) + " " + str(row.get('Title', ''))
    m = re.search(r'\b(128|256|512|1024)\s*(gb|g|tb)?\b', text, flags=re.IGNORECASE)
    if m:
        return m.group(1)

    return None

def map_launch_price_ultra(row):
    model_num = extract_samsung_ultra_model_number(row)
    if not model_num:
        return np.nan
    storage = extract_storage(row)
    if not storage:
        return np.nan
    price_map = samsung_ultra_launch_price.get(model_num.strip())
    if not price_map:
        return np.nan
    return price_map.get(storage, np.nan)

data['First_Release_Price'] = data.apply(map_launch_price_ultra, axis=1)

# ------------------------------------------------------------
# 4) AGE AT SALE (months)
# ------------------------------------------------------------
data['Age_at_Sale'] = (
    (data['Sold Date'] - data['Release Date']).dt.days / 30.44
)

# ------------------------------------------------------------
# 5) BUILD REGRESSION DATAFRAME
# ------------------------------------------------------------
mask = (
    data['Age_at_Sale'].notna() &
    data['Price_num'].notna() &
    data['First_Release_Price'].notna() &
    (data['First_Release_Price'] > 0)
)

df = data.loc[mask].copy()

# price ratio = sold price / launch price
df['Price_ratio'] = df['Price_num'] / df['First_Release_Price']

# storage numeric
df['Storage_num'] = df.apply(lambda r: float(extract_storage(r) or np.nan), axis=1)

df['Year_of_Sale']  = df['Sold Date'].dt.year
df['Month_of_Sale'] = df['Sold Date'].dt.month

# --- Condition cleanup (if column exists) ---
if 'Condition' in df.columns:
    df['Condition'] = (
        df['Condition']
          .astype(str).str.strip().str.title()
    )
    unknowns = {'Unknown', 'Unspecified', '', 'None', 'Na', 'Nan'}
    df.loc[df['Condition'].isin(unknowns), 'Condition'] = np.nan
else:
    df['Condition'] = np.nan  # no column → treat as missing

# Drop rows with NaN in key numeric fields
df = df.dropna(subset=['Age_at_Sale', 'Price_num', 'First_Release_Price', 'Storage_num'])

if df.empty:
    raise ValueError("No valid rows available for Ultra regression after filtering. Check Release Date / launch price / storage mapping.")

# --------------------------------------------------------
# 6) ONE-HOT ENCODE CONDITION (IF WE HAVE ANY)
# --------------------------------------------------------
has_any_condition = df['Condition'].notna().any()

if has_any_condition:
    enc = OneHotEncoder(drop=None, sparse_output=False, handle_unknown='ignore')
    cond_mat = enc.fit_transform(df[['Condition']])
    cond_cols = enc.get_feature_names_out(['Condition'])
    cond_df = pd.DataFrame(cond_mat, columns=cond_cols, index=df.index)
else:
    enc = None
    cond_cols = []
    cond_df = pd.DataFrame(index=df.index)

# Numeric features
X_num = df[['Age_at_Sale', 'Storage_num', 'Year_of_Sale', 'Month_of_Sale']]
X = pd.concat([X_num, cond_df], axis=1)
y = df['Price_ratio']

good = X.notna().all(axis=1) & y.notna()
X = X.loc[good]
y = y.loc[good]

if X.empty:
    raise ValueError("No rows left after cleaning NaNs in Ultra feature matrix.")

# --------------------------------------------------------
# 7) FIT MODEL
# --------------------------------------------------------
model = lm.LinearRegression()
model.fit(X, y)

print("=== Samsung S Ultra (S22 Ultra–S25 Ultra) Model Fit ===")
print("Samples:", len(y))
print("Intercept:", model.intercept_)
for name, coef in zip(X.columns, model.coef_):
    print(f"{name}: {coef:.6f}")

# --------------------------------------------------------
# 8) PREDICTION HELPER (ULTRA SERIES)
# --------------------------------------------------------
def predict_samsung_ultra_price(age_months, storage_gb, year, month, condition, launch_price):
    """
    age_months  : float  (Age_at_Sale in months)
    storage_gb  : int/float (e.g., 256, 512, 1024)
    year        : int   (year of sale, e.g. 2026)
    month       : int   (1–12)
    condition   : str   ('Excellent', 'Very Good', 'Good', 'Fair', etc.)
    launch_price: float (First_Release_Price for that Ultra model + storage)
    """
    base = pd.DataFrame({
        'Age_at_Sale':   [age_months],
        'Storage_num':   [storage_gb],
        'Year_of_Sale':  [year],
        'Month_of_Sale': [month],
        'Condition':     [str(condition).strip().str.title()]
    })

    if enc is not None and len(cond_cols) > 0:
        cond_new = pd.DataFrame(
            enc.transform(base[['Condition']]),
            columns=cond_cols,
            index=base.index
        )
    else:
        cond_new = pd.DataFrame(index=base.index)

    X_new = pd.concat([
        base[['Age_at_Sale', 'Storage_num', 'Year_of_Sale', 'Month_of_Sale']],
        cond_new
    ], axis=1)

    # align with model columns
    X_new = X_new.reindex(columns=X.columns, fill_value=0)

    ratio = model.predict(X_new)[0]
    return ratio * float(launch_price)

# --------------------------------------------------------
# 9) EXAMPLE USAGE (uncomment to test)
# --------------------------------------------------------
# lp = samsung_ultra_launch_price['24']['256']
# pred = predict_samsung_ultra_price(12, 256, 2026, 1, "Excellent", lp)
# print(f"Predicted S24 Ultra resale price: ${pred:.2f}")
# Out:
# === Samsung S Ultra (S22 Ultra–S25 Ultra) Model Fit ===
# Samples: 409
# Intercept: -79.44986065016309
# Age_at_Sale: -0.010182
# Storage_num: -0.000023
# Year_of_Sale: 0.039584
# Month_of_Sale: -0.000677
# Condition_Excellent: 0.023901
# Condition_Good: -0.022320
# Condition_Very Good: -0.001580

# %%
# === Samsung S Ultra resale regression (Galaxy S22 Ultra–S25 Ultra, numeric Condition + RMSE, no year/month) ===

import re
import numpy as np
import pandas as pd
import sklearn.linear_model as lm
from sklearn.metrics import root_mean_squared_error

# ------------------------------------------------------------
# 1) LOAD / PREP SAMSUNG ULTRA DATA
# ------------------------------------------------------------

# If `data` not already defined, load from CSV
if 'data' not in globals():
    data = pd.read_csv('Samsung_Series_Ultra_Combined.csv')  # <-- change filename if needed

# Clean column names and dates
data = data.rename(columns=str.strip).copy()
data['Sold Date'] = pd.to_datetime(data['Sold Date'], errors='coerce')

# Numeric sold price
data['Price_num'] = (
    data['Price']
        .astype(str)
        .str.replace('$', '', regex=False)
        .str.replace(',', '', regex=False)
        .astype(float)
)

# ------------------------------------------------------------
# 2) RELEASE MONTHS FOR S22 Ultra–S25 Ultra
# ------------------------------------------------------------
release_month_map_ultra = {
    '22': "2022-02",  # S22 Ultra Feb 2022
    '23': "2023-02",  # S23 Ultra Feb 2023
    '24': "2024-01",  # S24 Ultra Jan 2024
    '25': "2025-02",  # S25 Ultra early 2025 (assumed)
}

def extract_samsung_ultra_model_number(row):
    """
    Extract S number (22, 23, 24, 25) for ULTRA models like:
      'Galaxy S22 Ultra'
      'Samsung Galaxy S23 Ultra 256GB'
    """
    text = str(row.get('Model', '') or row.get('Title', ''))
    m = re.search(
        r'galaxy\s*s\s*(22|23|24|25)\s*ultra\b',
        text,
        flags=re.IGNORECASE
    )
    if m:
        return m.group(1)  # '22', '23', '24', '25'
    return None

def map_release_month_ultra(row):
    model_num = extract_samsung_ultra_model_number(row)
    if not model_num:
        return np.nan
    return release_month_map_ultra.get(model_num.strip(), np.nan)

data['Release Date'] = data.apply(map_release_month_ultra, axis=1)
data['Release Date'] = pd.to_datetime(data['Release Date'], errors='coerce')

# ------------------------------------------------------------
# 3) Samsung Ultra Launch Prices (US MSRP)
# ------------------------------------------------------------
samsung_ultra_launch_price = {
    # S22 Ultra : 128/256/512/1TB
    '22': { '128': 1199.0, '256': 1299.0, '512': 1399.0, '1024': 1599.0 },

    # S23 Ultra : base 256GB, no 128GB
    '23': { '256': 1199.0, '512': 1379.0, '1024': 1619.0 },

    # S24 Ultra
    '24': { '256': 1299.0, '512': 1419.0, '1024': 1659.0 },

    # S25 Ultra : assume same tiers as S24 Ultra
    '25': { '256': 1299.0, '512': 1419.0, '1024': 1659.0 },
}

def extract_storage(row):
    """Extract storage (GB) from Storage, Model, Title."""
    # direct columns first
    for col in ['Storage', 'Capacity', 'Memory', 'Storage Capacity']:
        if col in row.index and pd.notna(row[col]):
            m = re.search(r'(128|256|512|1024)', str(row[col]))
            if m:
                return m.group(1)

    # fallback: parse from full text
    text = str(row.get('Model', '')) + " " + str(row.get('Title', ''))
    m = re.search(r'\b(128|256|512|1024)\s*(gb|g|tb)?\b', text, flags=re.IGNORECASE)
    if m:
        return m.group(1)

    return None

def map_launch_price_ultra(row):
    model_num = extract_samsung_ultra_model_number(row)
    if not model_num:
        return np.nan
    storage = extract_storage(row)
    if not storage:
        return np.nan
    price_map = samsung_ultra_launch_price.get(model_num.strip())
    if not price_map:
        return np.nan
    return price_map.get(storage, np.nan)

data['First_Release_Price'] = data.apply(map_launch_price_ultra, axis=1)

# ------------------------------------------------------------
# 4) AGE AT SALE (months)
# ------------------------------------------------------------
data['Age_at_Sale'] = (
    (data['Sold Date'] - data['Release Date']).dt.days / 30.44
)

# ------------------------------------------------------------
# 5) BUILD REGRESSION DATAFRAME
# ------------------------------------------------------------
mask = (
    data['Age_at_Sale'].notna() &
    data['Price_num'].notna() &
    data['First_Release_Price'].notna() &
    (data['First_Release_Price'] > 0)
)

df = data.loc[mask].copy()

# price ratio = sold price / launch price
df['Price_ratio'] = df['Price_num'] / df['First_Release_Price']

# storage numeric
df['Storage_num'] = df.apply(
    lambda r: float(extract_storage(r) or np.nan),
    axis=1
)

# Condition cleanup (assume column exists)
if 'Condition' in df.columns:
    df['Condition'] = (
        df['Condition']
          .astype(str).str.strip().str.title()
    )
else:
    df['Condition'] = np.nan

unknowns = {'Unknown', 'Unspecified', '', 'None', 'Na', 'Nan'}
df.loc[df['Condition'].isin(unknowns), 'Condition'] = np.nan

# Drop rows with missing key numeric fields or condition
df = df.dropna(subset=['Age_at_Sale', 'Price_num', 'First_Release_Price', 'Storage_num', 'Condition'])

if df.empty:
    raise ValueError("No valid rows available for Ultra regression after filtering. Check Release Date / launch price / storage / condition mapping.")

# ------------------------------------------------------------
# Condition as numeric (NO one-hot encoding)
# ------------------------------------------------------------
cond_map = {
    'Excellent': 3,
    'Very Good': 2,
    'Good': 1,
    'Fair': 0,
}

# Overwrite Condition with numeric so it shows as "Condition" in coefficients
df['Condition'] = df['Condition'].map(cond_map)
df = df.dropna(subset=['Condition'])

# Feature matrix: ONLY age, storage, Condition (numeric)
X = df[['Age_at_Sale', 'Storage_num', 'Condition']].apply(
    pd.to_numeric, errors='coerce'
)
y = pd.to_numeric(df['Price_ratio'], errors='coerce')

good = X.notna().all(axis=1) & y.notna()
X = X.loc[good]
y = y.loc[good]

if X.empty:
    raise ValueError("No rows left after cleaning NaNs in Ultra feature matrix.")

# --------------------------------------------------------
# 6) FIT MODEL + RMSE
# --------------------------------------------------------
model = lm.LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)
rmse = root_mean_squared_error(y, y_pred)

print("=== Samsung S Ultra (S22 Ultra–S25 Ultra) Model Fit (numeric Condition, no year/month) ===")
print("Samples:", len(y))
print("RMSE:", rmse)
print("Intercept:", model.intercept_)
for name, coef in zip(X.columns, model.coef_):
    print(f"{name}: {coef:.6f}")

# --------------------------------------------------------
# 7) PREDICTION HELPER (ULTRA SERIES)
# --------------------------------------------------------
def predict_samsung_ultra_price(age_months, storage_gb, condition, launch_price):
    """
    age_months  : float  (Age_at_Sale in months)
    storage_gb  : int/float (e.g., 256, 512, 1024)
    condition   : str   ('Excellent', 'Very Good', 'Good', 'Fair', etc.)
    launch_price: float (First_Release_Price for that Ultra model + storage)
    """
    cond_val = cond_map.get(str(condition).strip().title())
    if cond_val is None:
        raise ValueError(f"Unknown condition: {condition}")

    base = pd.DataFrame({
        'Age_at_Sale': [age_months],
        'Storage_num': [storage_gb],
        'Condition':   [cond_val],
    })

    # Ensure same column order as training
    X_new = base[X.columns]

    ratio = model.predict(X_new)[0]
    return ratio * float(launch_price)

# --------------------------------------------------------
# 8) EXAMPLE USAGE (uncomment to test)
# --------------------------------------------------------
# lp = samsung_ultra_launch_price['24']['256']
# pred = predict_samsung_ultra_price(12, 256, "Excellent", lp)
# print(f"Predicted S24 Ultra resale price: ${pred:.2f}")
# Out:
# === Samsung S Ultra (S22 Ultra–S25 Ultra) Model Fit (numeric Condition, no year/month) ===
# Samples: 409
# RMSE: 0.029393355780788073
# Intercept: 0.6548901285162497
# Age_at_Sale: -0.010182
# Storage_num: -0.000022
# Condition: 0.023514
