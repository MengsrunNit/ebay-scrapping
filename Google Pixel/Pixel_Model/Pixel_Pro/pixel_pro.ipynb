# %%
import re
import pandas as pd

pixel6pro = pd.read_csv('pixel_6_pro_only.csv')

# Step 1: Remove rows with '|' (multiple model options)
pixel6pro = pixel6pro[~pixel6pro['Title'].str.contains(r'\|', regex=True, na=False)]

# Step 2: Remove titles that list multiple models like "6 - 6 Pro" or "7a / 7 / 7 Pro"
pattern_multi = r'\b(?:[1-9][0-9]?)\b\s*[-/|]\s*\b(?:[1-9][0-9]?)(?:\s*(?:Pro|XL|a))?\b'
pixel6pro = pixel6pro[~pixel6pro['Title'].str.contains(pattern_multi, flags=re.IGNORECASE, na=False)]

# Step 3: Keep only "Pixel 6 Pro" (not 6, 6 XL, 6a, etc.)
pixel6pro = pixel6pro[
    pixel6pro['Title'].str.contains(r'\bPixel\s*6\s*Pro\b', flags=re.IGNORECASE, na=False)
    & ~pixel6pro['Title'].str.contains(r'\b6\s*(?:XL|a)\b', flags=re.IGNORECASE, na=False)
]

# Preview
pixel6pro
# Out:
#     Page                                              Title    Price  \
# 0      1  Google Pixel 6 PRO 5G Android Unlocked Smartph...  $182.99
# 1      1  Google Pixel 6 Pro G8V0U Unlocked 128GB Cloudy...  $164.99
# 2      1  Google Pixel 6 Pro G8V0U Unlocked 128GB Stormy...  $159.99
# 3      1           Google Pixel 6 Pro 128GB Unlocked - Good  $163.99
# 4      1  Google Pixel 6 Pro - 256GB Stormy Black *UNLOC...  $206.99
# ..   ...                                                ...      ...
# 56     2  Google Pixel 6 Pro 128GB (Unlocked) - Cloudy W...  $189.98
# 57     2   Google Pixel 6 Pro 128GB 5G Unlocked - Very Good  $179.99
# 58     2  Google Pixel 6 Pro 512GB (Unlocked) - Stormy B...  $214.95
# 59     2      Google Pixel 6 Pro 128GB Unlocked - Excellent  $208.95
# 60     2  Google Pixel 6 Pro - 128GB - Stormy Black - Un...  $178.27
#
#      Sold Date                                   Link  \
# 0   2025-10-22  https://www.ebay.com/itm/195929387830
# ...

# %%
import re
import pandas as pd

pixel7pro = pd.read_csv('pixel_7_pro_only.csv')

# Step 1: Remove rows with '|' (multiple model options)
pixel7pro = pixel7pro[~pixel7pro['Title'].str.contains(r'\|', regex=True, na=False)]

# Step 2: Remove titles that list multiple models like "7 - 7 Pro" or "7a / 7 / 7 Pro"
pattern_multi = r'\b(?:[1-9][0-9]?)\b\s*[-/|]\s*\b(?:[1-9][0-9]?)(?:\s*(?:Pro|XL|a))?\b'
pixel7pro = pixel7pro[~pixel7pro['Title'].str.contains(pattern_multi, flags=re.IGNORECASE, na=False)]

# Step 3: Keep only "Pixel 7 Pro" (not 7, 7 XL, 7a, etc.)
pixel7pro = pixel7pro[
    pixel7pro['Title'].str.contains(r'\bPixel\s*7\s*Pro\b', flags=re.IGNORECASE, na=False)
    & ~pixel7pro['Title'].str.contains(r'\b7\s*(?:XL|a)\b', flags=re.IGNORECASE, na=False)
]

# Preview
pixel7pro
# Out:
#      Page                                              Title    Price  \
# 0       1  Google Pixel 7 Pro 5G (128GB, 12GB) 6.7" Fully...  $289.99
# 1       1  Google Pixel 7 Pro Unlocked All Colors/Memory ...  $259.99
# 2       1           Google Pixel 7 Pro 256GB Unlocked - Good  $259.99
# 3       1      Google Pixel 7 Pro 256GB Unlocked - Very Good  $279.99
# 4       1  Google Pixel 7 Pro 128GB 256GB 512GB 50MP Fact...  $229.88
# ..    ...                                                ...      ...
# 104     1        Google Pixel 7 Pro 256GB (Unlocked) - Hazel  $326.96
# 105     1  Google Pixel 7 Pro - 128GB - Black White Hazel...  $246.99
# 106     1      Google Pixel 7 Pro 128GB Unlocked - Excellent  $265.95
# 107     1  Google Pixel 7 Pro 5G UW GE2AE 128GB Verizon U...  $338.94
# 108     1  Google Pixel 7 Pro 128GB Snow Unlocked Excelle...  $289.99
#
#       Sold Date                                   Link  \
# 0    2025-08-02  https://www.ebay.com/itm/134779506570
# ...

# %%
import re
import pandas as pd

pixel8pro = pd.read_csv('pixel_8_pro_only.csv')

# Step 1: Remove rows with '|' (multiple model options)
pixel8pro = pixel8pro[~pixel8pro['Title'].str.contains(r'\|', regex=True, na=False)]

# Step 2: Remove titles that list multiple models like "8 - 8 Pro" or "7a / 8 / 8 Pro"
pattern_multi = r'\b(?:[1-9][0-9]?)\b\s*[-/|]\s*\b(?:[1-9][0-9]?)(?:\s*(?:Pro|XL|a))?\b'
pixel8pro = pixel8pro[~pixel8pro['Title'].str.contains(pattern_multi, flags=re.IGNORECASE, na=False)]

# Step 3: Keep only "Pixel 8 Pro" (not 8, 8 XL, 8a, etc.)
pixel8pro = pixel8pro[
    pixel8pro['Title'].str.contains(r'\bPixel\s*8\s*Pro\b', flags=re.IGNORECASE, na=False)
    & ~pixel8pro['Title'].str.contains(r'\b8\s*(?:XL|a)\b', flags=re.IGNORECASE, na=False)
]

# Preview
pixel8pro
# Out:
#      Page                                              Title    Price  \
# 0       1  Google Pixel 8 Pro 256GB Factory Unlocked - Ex...  $392.99
# 1       1  Google Pixel 8 Pro 128GB Black Obsidian - Fact...  $359.99
# 2       1  Google Pixel 8 Pro - 128GB - Unlocked - Excell...  $445.00
# 3       1      Google Pixel 8 Pro 256GB Unlocked - Excellent  $449.99
# 4       1  Google Pixel 8 Pro 128GB Unlocked GA04834US 6....  $374.99
# ..    ...                                                ...      ...
# 98      2   Google Pixel 8 Pro 128GB 5G Unlocked - Very Good  $349.99
# 99      2  Google Pixel 8 PRO 256GB 5G (UNLOCKED) Smartph...  $359.99
# 100     2  Google Pixel 8 PRO 512GB 5G (UNLOCKED) Smartph...  $499.99
# 101     2          Google Pixel 8 Pro 128GB (Unlocked) - Bay  $326.98
# 102     2  Google Pixel 8 Pro 128GB - Mint (Unlocked) G1M...  $399.95
#
#       Sold Date                                   Link  \
# 0    2025-10-22  https://www.ebay.com/itm/227006298920
# ...

# %%
import re
import pandas as pd

pixel9pro = pd.read_csv('pixel_9_pro_only.csv')

# Step 1: Remove rows with '|' (multiple model options)
pixel9pro = pixel9pro[~pixel9pro['Title'].str.contains(r'\|', regex=True, na=False)]

# Step 2: Remove titles that list multiple models like "9 - 9 Pro" or "8 / 9 / 9 Pro"
pattern_multi = r'\b(?:[1-9][0-9]?)\b\s*[-/|]\s*\b(?:[1-9][0-9]?)(?:\s*(?:Pro|XL|a|Fold))?\b'
pixel9pro = pixel9pro[~pixel9pro['Title'].str.contains(pattern_multi, flags=re.IGNORECASE, na=False)]

# Step 3: Keep only "Pixel 9 Pro" (not 9, 9 XL, 9a, 9 Fold, etc.)
pixel9pro = pixel9pro[
    pixel9pro['Title'].str.contains(r'\bPixel\s*9\s*Pro\b', flags=re.IGNORECASE, na=False)
    & ~pixel9pro['Title'].str.contains(r'\b9\s*(?:XL|a|Fold)\b', flags=re.IGNORECASE, na=False)
    & ~pixel9pro['Title'].str.contains(r'\bFold\b', flags=re.IGNORECASE, na=False)  # <— extra safety filter
]

# Preview
pixel9pro
# Out:
#      Page                                              Title    Price  \
# 0       1   Google Pixel 9 Pro 128GB Factory Unlocked - Good  $494.99
# 1       1  Google Pixel 9 Pro 128GB Porcelain Unlocked Ve...  $529.99
# 2       1  Google Pixel 9 Pro 512GB Hazel Unlocked Excell...  $809.99
# 3       1  Google Pixel 9 Pro 5G (128GB, 16GB) 6.3" Fully...  $595.40
# 4       1  Google Pixel 9 Pro 128GB Factory Unlocked - Ex...  $563.99
# ..    ...                                                ...      ...
# 111     1  Google Pixel 9 Pro 128GB - White Porcelain - N...  $599.99
# 112     1  Google Pixel 9 Pro 128GB - White Porcelain - U...  $599.99
# 113     1  Google Pixel 9 Pro - Unlocked - Porcelain - 12...  $535.00
# 115     1  Google Pixel 9 Pro - Unlocked - Obsidian - 256...  $679.00
# 117     1  Google Pixel 9 Pro - Unlocked - Hazel - 512GB ...  $749.00
#
#       Sold Date                                   Link  \
# 0    2025-10-22  https://www.ebay.com/itm/226977900964
# ...

# %%
import re
import pandas as pd

pixel9proxl = pd.read_csv('pixel_9_pro_xl_only.csv')

# Step 1: Remove rows with '|' (multiple model options)
pixel9proxl = pixel9proxl[~pixel9proxl['Title'].str.contains(r'\|', regex=True, na=False)]

# Step 2: Remove titles that list multiple models like "9 - 9 Pro XL" or "8 / 9 / 9 Pro XL"
pattern_multi = r'\b(?:[1-9][0-9]?)\b\s*[-/|]\s*\b(?:[1-9][0-9]?)(?:\s*(?:Pro|XL|a|Fold))?\b'
pixel9proxl = pixel9proxl[~pixel9proxl['Title'].str.contains(pattern_multi, flags=re.IGNORECASE, na=False)]

# Step 3: Keep only "Pixel 9 Pro XL" (not 9, 9 Pro, 9a, 9 Fold, etc.)
pixel9proxl = pixel9proxl[
    pixel9proxl['Title'].str.contains(r'\bPixel\s*9\s*Pro\s*XL\b', flags=re.IGNORECASE, na=False)
    & ~pixel9proxl['Title'].str.contains(r'\b9\s*(?:a|Fold)\b', flags=re.IGNORECASE, na=False)
    & ~pixel9proxl['Title'].str.contains(r'\bFold\b', flags=re.IGNORECASE, na=False)
]

# Preview
pixel9proxl
# Out:
#     Page                                              Title    Price  \
# 0      1   Google Pixel 9 Pro XL 256GB Unlocked - Excellent  $646.95
# 1      1  Google Pixel 9 Pro XL - Unlocked - Hazel - 128...  $529.00
# 2      1  Google Pixel 9 Pro XL 128GB - Factory Unlocked...  $549.99
# 3      1  Google Pixel 9 Pro XL - GGX8B - 128GB Obsidian...  $552.99
# 4      1  Google Pixel 9 Pro XL 256GB Obsidian Unlocked ...  $609.99
# ..   ...                                                ...      ...
# 94     1  Google Pixel 9 Pro Xl Fully Unlocked 6.8in 256...  $703.00
# 95     1  Google Pixel 9 Pro XL 256GB (Unlocked) - Rose ...  $699.95
# 96     1  Google Pixel 9 Pro XL 256GB Rose Quartz Unlock...  $679.99
# 97     1  Google Pixel 9 Pro XL - Unlocked - Hazel - 128...  $577.00
# 98     1  Google Pixel 9 Pro XL - 256GB - Obsidian - (Ca...  $709.98
#
#      Sold Date                                   Link  \
# 0   2025-10-22  https://www.ebay.com/itm/389018583024
# ...

# %%
import re
import pandas as pd

pixel10pro = pd.read_csv('pixel_10_pro_only.csv')

# Step 1: Remove rows with '|' (multiple model options)
pixel10pro = pixel10pro[~pixel10pro['Title'].str.contains(r'\|', regex=True, na=False)]

# Step 2: Remove titles that list multiple models like "10 - 10 Pro" or "9 / 10 / 10 Pro"
pattern_multi = r'\b(?:[1-9][0-9]?)\b\s*[-/|]\s*\b(?:[1-9][0-9]?)(?:\s*(?:Pro|XL|a|Fold))?\b'
pixel10pro = pixel10pro[~pixel10pro['Title'].str.contains(pattern_multi, flags=re.IGNORECASE, na=False)]

# Step 3: Keep only "Pixel 10 Pro"; exclude XL/a/Fold and especially "10 Pro XL"
pixel10pro = pixel10pro[
    # must contain "Pixel 10 Pro" and NOT immediately followed by XL
    pixel10pro['Title'].str.contains(r'\bPixel\s*10\s*Pro\b(?!\s*XL\b)', flags=re.IGNORECASE, na=False)
    # exclude any form of "10 Pro XL" (hyphen, spaces, etc.)
    & ~pixel10pro['Title'].str.contains(r'\b10\s*Pro\s*[-/ ]*\s*XL\b', flags=re.IGNORECASE, na=False)
    # extra guards
    & ~pixel10pro['Title'].str.contains(r'\b10\s*(?:XL|a|Fold)\b', flags=re.IGNORECASE, na=False)
    & ~pixel10pro['Title'].str.contains(r'\bFold\b', flags=re.IGNORECASE, na=False)
]

# Preview
pixel10pro
# Out:
#    Page                                              Title    Price  \
# 3     1  Google Pixel 10 Pro, 128GB Unlocked Very Good ...  $729.99
# 4     1  Google Pixel 10 Pro - 256GB - Obsidian (Unlock...  $814.95
#
#     Sold Date                                   Link  \
# 3  2025-10-17  https://www.ebay.com/itm/357569690400
# 4  2025-10-05  https://www.ebay.com/itm/146835964730
#
#                                           Image Link Storage  Condition  \
# 3  https://i.ebayimg.com/images/g/OWYAAeSwgLxouck...  128 GB  Very Good
# 4  https://i.ebayimg.com/images/g/15wAAeSw1EJoyX3...  256 GB  Excellent
#
#    PartsOnly         Model  Pixel_10_Pro
# 3      False  Pixel 10 Pro          True
# 4      False  Pixel 10 Pro          True

# %%
import re
import pandas as pd

pixel10proxl = pd.read_csv('pixel_10_pro_xl_only.csv')

# Step 1 – Remove rows with '|' (multiple model options)
pixel10proxl = pixel10proxl[~pixel10proxl['Title'].str.contains(r'\|', regex=True, na=False)]

# Step 2 – Remove titles that list multiple models like "10 – 10 Pro XL" or "9 / 10 / 10 Pro XL"
pattern_multi = r'\b(?:[1-9][0-9]?)\b\s*[-/|]\s*\b(?:[1-9][0-9]?)(?:\s*(?:Pro|XL|a|Fold))?\b'
pixel10proxl = pixel10proxl[~pixel10proxl['Title'].str.contains(pattern_multi, flags=re.IGNORECASE, na=False)]

# Step 3 – Keep only "Pixel 10 Pro XL" (not 10, 10 Pro, 10 a, 10 Fold, etc.)
pixel10proxl = pixel10proxl[
    pixel10proxl['Title'].str.contains(r'\bPixel\s*10\s*Pro\s*XL\b', flags=re.IGNORECASE, na=False)
    & ~pixel10proxl['Title'].str.contains(r'\b10\s*(?:a|Fold)\b', flags=re.IGNORECASE, na=False)
    & ~pixel10proxl['Title'].str.contains(r'\bFold\b', flags=re.IGNORECASE, na=False)
]

# Preview
pixel10proxl.head()
# Out:
#    Page                                              Title    Price  \
# 0     1  Google Pixel 10 Pro XL 256GB Unlocked Very Goo...  $859.99
# 1     1  Google Pixel 10 Pro XL Unlocked 256GB 6.8" 5G ...  $849.99
# 2     1  Google Pixel 10 Pro XL - 256 GB - Jade (Unlock...  $819.95
#
#     Sold Date                                   Link  \
# 0  2025-10-22  https://www.ebay.com/itm/357569770144
# 1  2025-10-16  https://www.ebay.com/itm/326812942934
# 2  2025-10-15  https://www.ebay.com/itm/127403978863
#
#                                           Image Link Storage  Condition  \
# 0  https://i.ebayimg.com/images/g/clMAAeSw4W9ouc3...  256 GB  Very Good
# 1  https://i.ebayimg.com/images/g/SnMAAeSwV0Zo6jM...  256 GB    Unknown
# 2  https://i.ebayimg.com/images/g/D8UAAeSwcGJo27Y...  256 GB       Good
#
#    PartsOnly            Model  Pixel_10_Pro_XL
# 0      False  Pixel 10 Pro XL             True
# 1      False  Pixel 10 Pro XL             True
# ...

# %%
#I want to combine all cleaned data from pixel6pro, pixel7pro, pixel8pro, pixel9pro ,pixel9proxl and pixel10pro, pixel10proxl into one dataframe called pixel_base
pixel_base = pd.concat([pixel6pro, pixel7pro, pixel8pro, pixel9pro,pixel9proxl, pixel10pro, pixel10proxl], ignore_index=True)
pixel_base
#export to csv
pixel_base.to_csv('pixel_pro.csv', index=False)

# %%
data = pd.read_csv('pixel_pro.csv')
data['Sold Date'] = pd.to_datetime(data['Sold Date'])
data['year']= data['Sold Date'].dt.year
data['Month'] = data['Sold Date'].dt.month
data['Price_num'] = data['Price'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
import pandas as pd

# --- RELEASE DATE MAPPING FOR PIXEL PRO SERIES ONLY ---

release_map = {
    "Pixel 6 Pro":     "2021-10",
    "Pixel 7 Pro":     "2022-10",
    "Pixel 8 Pro":     "2023-10",
    "Pixel 9 Pro":     "2024-08",
    "Pixel 9 Pro XL":  "2024-08",
    "Pixel 10 Pro":    "2025-10",  # placeholder — adjust when official
    "Pixel 10 Pro XL": "2025-10",  # placeholder — adjust when official
}

data['Release Date'] = data['Model'].replace(release_map)

# Convert to datetime
data['Release Date'] = pd.to_datetime(data['Release Date'], errors='coerce')

# --- COMPUTE AGE IN MONTHS ---
data["Age_at_Sale"] = (
    (data['Sold Date'] - data['Release Date']).dt.days / 30.44
).round(2)
data
# Out:
#      Page                                              Title    Price  \
# 0       1  Google Pixel 6 PRO 5G Android Unlocked Smartph...  $182.99
# 1       1  Google Pixel 6 Pro G8V0U Unlocked 128GB Cloudy...  $164.99
# 2       1  Google Pixel 6 Pro G8V0U Unlocked 128GB Stormy...  $159.99
# 3       1           Google Pixel 6 Pro 128GB Unlocked - Good  $163.99
# 4       1  Google Pixel 6 Pro - 256GB Stormy Black *UNLOC...  $206.99
# ..    ...                                                ...      ...
# 452     1  Google Pixel 10 Pro, 128GB Unlocked Very Good ...  $729.99
# 453     1  Google Pixel 10 Pro - 256GB - Obsidian (Unlock...  $814.95
# 454     1  Google Pixel 10 Pro XL 256GB Unlocked Very Goo...  $859.99
# 455     1  Google Pixel 10 Pro XL Unlocked 256GB 6.8" 5G ...  $849.99
# 456     1  Google Pixel 10 Pro XL - 256 GB - Jade (Unlock...  $819.95
#
#      Sold Date                                   Link  \
# 0   2025-10-22  https://www.ebay.com/itm/195929387830
# ...

# %%
import re
import numpy as np
import pandas as pd

# --- Pixel Pro launch prices (US MSRP, confirmed / corrected) ---

pixel_pro_release_price_map = {
    # Pixel 6 Pro (Confirmed)
    'Pixel 6 Pro': {
        '128': 899.0,
        '256': 999.0,
        '512': 1099.0,
    },

    # Pixel 7 Pro (Confirmed)
    'Pixel 7 Pro': {
        '128': 899.0,
        '256': 999.0,
        '512': 1099.0,
    },

    # Pixel 8 Pro (Correct official MSRPs)
    'Pixel 8 Pro': {
        '128': 999.0,
        '256': 1059.0,
        '512': 1219.0,
        '1024': 1399.0,
    },

    # Pixel 9 Pro (Confirmed)
    'Pixel 9 Pro': {
        '128': 999.0,
        '256': 1099.0,
        '512': 1219.0,
        '1024': 1449.0,
    },

    # Pixel 9 Pro XL (Confirmed)
    'Pixel 9 Pro XL': {
        '128': 1099.0,
        '256': 1199.0,
        '512': 1319.0,
        '1024': 1549.0,
    },

    # Pixel 10 Pro (Confirmed 2025 MSRPs — no 1TB tier)
    'Pixel 10 Pro': {
        '128': 999.0,
        '256': 1099.0,
        '512': 1219.0,
    },

    # Pixel 10 Pro XL (Confirmed 2025 MSRPs — no 1TB tier)
    'Pixel 10 Pro XL': {
        '128': 1199.0,
        '256': 1299.0,
        '512': 1419.0,
    },
}

# --- Storage extractor ---

def extract_storage_from_row(row):
    """Extract storage size like '128', '256', '512', '1024' from columns or text."""
    for col in ['Storage', 'Capacity', 'Memory', 'Storage Capacity']:
        if col in row.index and pd.notna(row[col]):
            s = str(row[col])
            m = re.search(r'(64|128|256|512|1024)', s)
            if m:
                return m.group(1)

    text = f"{row.get('Model', '')} {row.get('Title', '')}"
    m = re.search(r'\b(64|128|256|512|1024)\s*(GB|G|TB|tb|gb)?\b', text, flags=re.IGNORECASE)
    if m:
        return m.group(1)

    return None

# --- Model key extractor ---

def extract_pixel_pro_model_key(row):
    """Match model text to one of the Pixel Pro model keys."""
    model = str(row.get('Model', '')).strip()

    for key in pixel_pro_release_price_map.keys():
        if model.startswith(key):
            return key

    title = str(row.get('Title', '')).strip()
    for key in pixel_pro_release_price_map.keys():
        if key in title:
            return key

    return None

# --- Price mapper ---

def map_pixel_pro_first_release_price(row):
    """Return launch MSRP based on model + storage."""
    model_key = extract_pixel_pro_model_key(row)
    if not model_key:
        return np.nan

    storage = extract_storage_from_row(row)
    if not storage:
        return np.nan

    return pixel_pro_release_price_map[model_key].get(storage, np.nan)

# --- Load data ---

if 'data' not in globals():
    try:
        data = pd.read_csv('Pixel_Pro_Combined.csv')
        if 'Sold Date' in data.columns:
            data['Sold Date'] = pd.to_datetime(data['Sold Date'], errors='coerce')
    except FileNotFoundError:
        raise FileNotFoundError("Pixel_Pro_Combined.csv not found.")

# --- Compute First Release Price ---

data['First_Release_Price'] = data.apply(map_pixel_pro_first_release_price, axis=1)

# --- Sanity check ---

for key in pixel_pro_release_price_map.keys():
    mask = data['Model'].astype(str).str.startswith(key, na=False)
    total = mask.sum()
    filled = (mask & data['First_Release_Price'].notna()).sum()
    print(f"{key}: filled {filled} / {total}")

display(data[data['First_Release_Price'].notna()].head())
# Out:
# Pixel 6 Pro: filled 60 / 61
# Pixel 7 Pro: filled 103 / 109
# Pixel 8 Pro: filled 98 / 103
# Pixel 9 Pro: filled 166 / 179
# Pixel 9 Pro XL: filled 89 / 99
# Pixel 10 Pro: filled 5 / 5
# Pixel 10 Pro XL: filled 3 / 3
#    Page                                              Title    Price  \
# 0     1  Google Pixel 6 PRO 5G Android Unlocked Smartph...  $182.99
# 1     1  Google Pixel 6 Pro G8V0U Unlocked 128GB Cloudy...  $164.99
# 2     1  Google Pixel 6 Pro G8V0U Unlocked 128GB Stormy...  $159.99
# 3     1           Google Pixel 6 Pro 128GB Unlocked - Good  $163.99
# 4     1  Google Pixel 6 Pro - 256GB Stormy Black *UNLOC...  $206.99
#
#    Sold Date                                   Link  \
# 0 2025-10-22  https://www.ebay.com/itm/195929387830
# 1 2025-10-21  https://www.ebay.com/itm/186676772935
# 2 2025-10-20  https://www.ebay.com/itm/176486191776
# 3 2025-10-20  https://www.ebay.com/itm/255889634358
# 4 2025-10-20  https://www.ebay.com/itm/146549898373
#
# ...

# %%
from matplotlib import pyplot as plt
import numpy as np

# Make sure column names are clean
data.rename(columns=str.strip, inplace=True)

# Use clean columns
x = data['Age_at_Sale']          # months since release
y = data['Price_num']            # resale price $

# Drop NaNs/infs before fitting
m = np.isfinite(x) & np.isfinite(y)
x = x[m].to_numpy()
y = y[m].to_numpy()

# Fit and build 3rd-degree polynomial
degree = 3
coeffs = np.polyfit(x, y, degree)
poly_eq = np.poly1d(coeffs)

# Smooth curve for the fit
x_line = np.linspace(x.min(), x.max(), 200)
y_line = poly_eq(x_line)

# Plot scatter + fitted curve
plt.scatter(x, y, s=15, alpha=0.6, label='Pixel 6 Pro–Pixel 10 Pro XL Data')
plt.plot(x_line, y_line, linewidth=2, label=f'{degree}rd-degree fit')

plt.xlabel('Age at Sale (Months)')
plt.ylabel('Price ($)')
plt.title('Pixel 6 Pro–Pixel 10 Pro XL Price Depreciation Over Time (3rd-degree Polynomial)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
import os

# Make sure column names are clean
data.rename(columns=str.strip, inplace=True)

# Use clean columns
x = data['Age_at_Sale']                 # months since release
price = data['Price_num']               # resale price $

# Use First_Release_Price calculated in the previous cell
# (Instead of 'Original_Price' which was commented out)
orig = data['First_Release_Price']      # original MSRP

# Compute value retention (%)
value_retention = (price / orig) * 100

# Drop NaNs/infs before fitting
m = np.isfinite(x) & np.isfinite(value_retention)
x = x[m].to_numpy()
y = value_retention[m].to_numpy()       # y is now retention %

# Fit and build 3rd-degree polynomial on retention
degree = 3
coeffs = np.polyfit(x, y, degree)
poly_eq = np.poly1d(coeffs)

# Smooth curve for the fit
x_line = np.linspace(x.min(), x.max(), 200)
y_line = poly_eq(x_line)

# Plot scatter + fitted curve
plt.scatter(x, y, s=15, alpha=0.6,
            label='Pixel Pro Model Data')
plt.plot(x_line, y_line, linewidth=2,
         label=f'{degree}rd-degree fit')

plt.xlabel('Age at Sale (Months)')
plt.ylabel('Value Retention (%)')
plt.title('Pixel Pro Model Value Retention Over Time (3rd-degree Polynomial)')
plt.legend()
plt.tight_layout()

# Save figure
os.makedirs('output', exist_ok=True)
plt.savefig('output/pixel_value_retention_polynomial_fit.png', dpi=300)

plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
import os

# Make sure column names are clean
data.rename(columns=str.strip, inplace=True)

# Use clean columns
x = data['Age_at_Sale']                 # months since release
price = data['Price_num']               # resale price $

# Use First_Release_Price 
orig = data['First_Release_Price']      # original MSRP

# Compute value retention (%)
value_retention = (price / orig) * 100

# Drop NaNs/infs before fitting
m = np.isfinite(x) & np.isfinite(value_retention)
x = x[m].to_numpy()
y = value_retention[m].to_numpy()       # y is now retention %

# Fit and build 3rd-degree polynomial on retention
degree = 3
coeffs = np.polyfit(x, y, degree)
poly_eq = np.poly1d(coeffs)

# Smooth curve for the fit
x_line = np.linspace(x.min(), x.max(), 200)
y_line = poly_eq(x_line)

# -------------------------------
# ⭐ GET EXACT TABLE VALUES
# -------------------------------
val_12 = poly_eq(12)
val_24 = poly_eq(24)

print("-" * 40)
print("TABLE VALUES FOR PIXEL PRO:")
print(f"12 Months: {val_12:.2f}%")
print(f"24 Months: {val_24:.2f}%")
print("-" * 40)

# Plot scatter + fitted curve
plt.scatter(x, y, s=15, alpha=0.6,
            label='Pixel Pro Model Data')
plt.plot(x_line, y_line, linewidth=2,
         label=f'{degree}rd-degree fit')

plt.xlabel('Age at Sale (Months)')
plt.ylabel('Value Retention (%)')
plt.title('Pixel Pro Model Value Retention Over Time')
plt.legend()
plt.tight_layout()

# Save figure (Renamed to be specific)
os.makedirs('output', exist_ok=True)
plt.savefig('output/pixel_pro_value_retention_polynomial_fit.png', dpi=300)

plt.show()
# Out:
# ----------------------------------------
# TABLE VALUES FOR PIXEL PRO:
# 12 Months: 60.58%
# 24 Months: 40.62%
# ----------------------------------------

# %%
from matplotlib import pyplot as plt
import numpy as np
import os

# [Load your 'data' DataFrame here]
# example: data = pd.read_csv("pixel_sales_data.csv")

# Make sure column names are clean
data.rename(columns=str.strip, inplace=True)

# Use clean columns
x = data['Age_at_Sale']                 # months since release
price = data['Price_num']               # resale price $

# Use First_Release_Price 
orig = data['First_Release_Price']      # original MSRP

# Compute value retention (%)
value_retention = (price / orig) * 100

# Drop NaNs/infs before fitting
m = np.isfinite(x) & np.isfinite(value_retention)
x = x[m].to_numpy()
y = value_retention[m].to_numpy()       # y is now retention %

# Fit and build 3rd-degree polynomial on retention
degree = 3
coeffs = np.polyfit(x, y, degree)
poly_eq = np.poly1d(coeffs)

# Smooth curve for the fit
# Ensure the line extends to at least 48 months for the visual
x_max = max(x.max(), 48)
x_line = np.linspace(x.min(), x_max, 200)
y_line = poly_eq(x_line)

# -------------------------------
# ⭐ GET EXACT TABLE VALUES
# -------------------------------
months_to_check = [3, 6, 12, 18, 24, 48]

print("-" * 40)
print("TABLE VALUES FOR PIXEL PRO:")
for month in months_to_check:
    val = poly_eq(month)
    print(f"{month} Months: {val:.2f}%")
print("-" * 40)

# Plot scatter + fitted curve
plt.figure(figsize=(10, 6)) # Added figure size for better visibility
plt.scatter(x, y, s=15, alpha=0.6,
            label='Pixel Pro Model Data')
plt.plot(x_line, y_line, linewidth=2, color='tab:orange',
         label=f'{degree}rd-degree fit')

# Optional: Add markers for the specific months requested
for month in months_to_check:
    val = poly_eq(month)
    if x.min() <= month <= x_max: # Only plot if within range
        plt.plot(month, val, 'ro', markersize=5) # Red dot

plt.xlabel('Age at Sale (Months)')
plt.ylabel('Value Retention (%)')
plt.title('Pixel Pro Model Value Retention Over Time')
plt.legend()
plt.tight_layout()

# Save figure (Renamed to be specific)
os.makedirs('output', exist_ok=True)
plt.savefig('output/pixel_pro_value_retention_polynomial_fit.png', dpi=300)

plt.show()
# Out:
# ----------------------------------------
# TABLE VALUES FOR PIXEL PRO:
# 3 Months: 76.55%
# 6 Months: 71.26%
# 12 Months: 60.58%
# 18 Months: 50.19%
# 24 Months: 40.62%
# 48 Months: 20.87%
# ----------------------------------------

# %%
from matplotlib import pyplot as plt
import numpy as np
import os

# [Load your 'data' DataFrame here]
# example: data = pd.read_csv("pixel_sales_data.csv")

# Make sure column names are clean
data.rename(columns=str.strip, inplace=True)

# Use clean columns
x = data['Age_at_Sale']                 # months since release
price = data['Price_num']               # resale price $

# Use First_Release_Price 
orig = data['First_Release_Price']      # original MSRP

# Compute value retention (%)
value_retention = (price / orig) * 100

# Drop NaNs/infs before fitting
m = np.isfinite(x) & np.isfinite(value_retention)
x = x[m].to_numpy()
y = value_retention[m].to_numpy()       # y is now retention %

# Fit and build 3rd-degree polynomial on retention
degree = 3
coeffs = np.polyfit(x, y, degree)
poly_eq = np.poly1d(coeffs)

# Smooth curve for the fit
# Ensure the line extends to at least 48 months for the visual
x_max = max(x.max(), 48)
x_line = np.linspace(x.min(), x_max, 200)
y_line = poly_eq(x_line)

# -------------------------------
# ⭐ GET EXACT TABLE VALUES
# -------------------------------
months_to_check = [3, 6, 12, 18, 24, 48]
rmse_val = 0.051574711607796635  # User-provided RMSE

print("-" * 40)
print("TABLE VALUES FOR PIXEL PRO:")
for month in months_to_check:
    val = poly_eq(month)
    print(f"{month} Months: {val:.2f}%")
print("-" * 40)
print(f"Model RMSE: {rmse_val}")
print("-" * 40)

# Plot scatter + fitted curve
plt.figure(figsize=(10, 6))
plt.scatter(x, y, s=15, alpha=0.6,
            label='Pixel Pro Model Data')
plt.plot(x_line, y_line, linewidth=2, color='tab:orange',
         label=f'{degree}rd-degree fit')

# Optional: Add markers for the specific months requested
for month in months_to_check:
    val = poly_eq(month)
    if x.min() <= month <= x_max: # Only plot if within range
        plt.plot(month, val, 'ro', markersize=5) 

# ⭐ Add RMSE Text Box to the plot
textstr = f'RMSE: {rmse_val:.5f}'
props = dict(boxstyle='round', facecolor='white', alpha=0.5)
plt.text(0.02, 0.05, textstr, transform=plt.gca().transAxes, fontsize=10,
        verticalalignment='bottom', bbox=props)

plt.xlabel('Age at Sale (Months)')
plt.ylabel('Value Retention (%)')
plt.title('Pixel Pro Model Value Retention Over Time')
plt.legend()
plt.tight_layout()

# Save figure (Renamed to be specific)
os.makedirs('output', exist_ok=True)
plt.savefig('output/pixel_pro_value_retention_polynomial_fit.png', dpi=300)

plt.show()
# Out:
# ----------------------------------------
# TABLE VALUES FOR PIXEL PRO:
# 3 Months: 76.55%
# 6 Months: 71.26%
# 12 Months: 60.58%
# 18 Months: 50.19%
# 24 Months: 40.62%
# 48 Months: 20.87%
# ----------------------------------------
# Model RMSE: 0.051574711607796635
# ----------------------------------------

# %%
# === Pixel Pro resale regression (Pixel 6 Pro–Pixel 10 Pro XL) ===

import re
import numpy as np
import pandas as pd
import sklearn.linear_model as lm
from sklearn.preprocessing import OneHotEncoder

# ------------------------------------------------------------
# 1) LOAD / PREP PIXEL PRO DATA
# ------------------------------------------------------------

# If `data` not already defined, load from CSV
if 'data' not in globals():
    data = pd.read_csv('Pixel_Pro_Combined.csv')  # <-- change filename if needed

# Clean column names and dates
data = data.rename(columns=str.strip).copy()
if 'Sold Date' in data.columns:
    data['Sold Date'] = pd.to_datetime(data['Sold Date'], errors='coerce')
else:
    raise KeyError("Expected a 'Sold Date' column in Pixel data.")

# Numeric sold price
data['Price_num'] = (
    data['Price']
        .astype(str)
        .str.replace('$', '', regex=False)
        .str.replace(',', '', regex=False)
        .astype(float)
)

# ------------------------------------------------------------
# 2) RELEASE MONTHS FOR PIXEL 6 PRO – PIXEL 10 PRO XL
# ------------------------------------------------------------

# Release months (YYYY-MM) – adjust if you have more precise dates
pixel_release_month_map = {
    'Pixel 6 Pro':     "2021-10",
    'Pixel 7 Pro':     "2022-10",
    'Pixel 8 Pro':     "2023-10",
    'Pixel 9 Pro':     "2024-08",
    'Pixel 9 Pro XL':  "2024-08",
    'Pixel 10 Pro':    "2025-10",  # adjust when you have exact launch month
    'Pixel 10 Pro XL': "2025-10",
}

# ------------------------------------------------------------
# 3) PIXEL PRO LAUNCH PRICES (US MSRP)
# ------------------------------------------------------------
# 6–9 Pro / Pro XL are your confirmed numbers.
# 10 Pro / 10 Pro XL base MSRPs are grounded in current info (128GB $999, 256GB $1099, etc.);
# higher tiers are reasonable approximations – update if you have official tables.

pixel_pro_release_price_map = {
    # Pixel 6 Pro (Confirmed)
    'Pixel 6 Pro': {
        '128': 899.0,
        '256': 999.0,
        '512': 1099.0,
    },

    # Pixel 7 Pro (Confirmed)
    'Pixel 7 Pro': {
        '128': 899.0,
        '256': 999.0,
        '512': 1099.0,
    },

    # Pixel 8 Pro (Corrected to official pricing)
    'Pixel 8 Pro': {
        '128': 999.0,
        '256': 1059.0,
        '512': 1219.0,
        '1024': 1399.0,
    },

    # Pixel 9 Pro (Confirmed)
    'Pixel 9 Pro': {
        '128': 999.0,
        '256': 1099.0,
        '512': 1219.0,
        '1024': 1449.0,
    },

    # Pixel 9 Pro XL (Confirmed)
    'Pixel 9 Pro XL': {
        '128': 1099.0,
        '256': 1199.0,
        '512': 1319.0,
        '1024': 1549.0,
    },

    # Pixel 10 Pro (2025) – base tiers from current MSRP, higher tiers approx.
    'Pixel 10 Pro': {
        '128': 999.0,   # official base MSRP
        '256': 1099.0,  # follows Pixel pricing pattern
        '512': 1219.0,  # consistent with 8/9 Pro 512 step
    },

    # Pixel 10 Pro XL (2025) – base 256 MSRP, higher tiers approx.
    'Pixel 10 Pro XL': {
        '128': 1199.0,  # if 128 XL exists; adjust if only 256 is base
        '256': 1299.0,  # 256GB MSRP (known pattern + deal deltas)
        '512': 1419.0,  # approximated – update with official table if you have it
    },
}

# ------------------------------------------------------------
# 4) HELPERS: STORAGE + MODEL KEY + MAPPING
# ------------------------------------------------------------

def extract_storage(row):
    """Extract storage (GB) from Storage, Model, Title."""
    # direct columns first
    for col in ['Storage', 'Capacity', 'Memory', 'Storage Capacity']:
        if col in row.index and pd.notna(row[col]):
            m = re.search(r'(64|128|256|512|1024)', str(row[col]))
            if m:
                return m.group(1)

    # fallback: parse from full text
    text = f"{row.get('Model', '')} {row.get('Title', '')}"
    m = re.search(r'\b(64|128|256|512|1024)\s*(gb|g|tb|TB|Gb)?\b', text, flags=re.IGNORECASE)
    if m:
        return m.group(1)

    return None


def extract_pixel_pro_model_key(row):
    """
    Map the row's Model/Title to one of the Pixel Pro keys:
      'Pixel 6 Pro', 'Pixel 7 Pro', 'Pixel 8 Pro',
      'Pixel 9 Pro', 'Pixel 9 Pro XL',
      'Pixel 10 Pro', 'Pixel 10 Pro XL'
    """
    model = str(row.get('Model', '')).strip()
    title = str(row.get('Title', '')).strip()

    for key in pixel_pro_release_price_map.keys():
        if model.startswith(key):
            return key

    for key in pixel_pro_release_price_map.keys():
        if key in title:
            return key

    return None


def map_release_month_pixel(row):
    key = extract_pixel_pro_model_key(row)
    if not key:
        return np.nan
    return pixel_release_month_map.get(key, np.nan)


def map_launch_price_pixel(row):
    key = extract_pixel_pro_model_key(row)
    if not key:
        return np.nan
    storage = extract_storage(row)
    if not storage:
        return np.nan
    price_map = pixel_pro_release_price_map.get(key, {})
    return price_map.get(storage, np.nan)


# Apply release date and launch price
data['Release Date'] = data.apply(map_release_month_pixel, axis=1)
data['Release Date'] = pd.to_datetime(data['Release Date'], errors='coerce')

data['First_Release_Price'] = data.apply(map_launch_price_pixel, axis=1)

# ------------------------------------------------------------
# 5) AGE AT SALE (months)
# ------------------------------------------------------------
data['Age_at_Sale'] = (
    (data['Sold Date'] - data['Release Date']).dt.days / 30.44
)

# ------------------------------------------------------------
# 6) BUILD REGRESSION DATAFRAME
# ------------------------------------------------------------
mask = (
    data['Age_at_Sale'].notna() &
    data['Price_num'].notna() &
    data['First_Release_Price'].notna() &
    (data['First_Release_Price'] > 0)
)

df = data.loc[mask].copy()

# price ratio = sold price / launch price
df['Price_ratio'] = df['Price_num'] / df['First_Release_Price']

# storage numeric
df['Storage_num'] = df.apply(lambda r: float(extract_storage(r) or np.nan), axis=1)

df['Year_of_Sale']  = df['Sold Date'].dt.year
df['Month_of_Sale'] = df['Sold Date'].dt.month

# --- Condition cleanup (if column exists) ---
if 'Condition' in df.columns:
    df['Condition'] = (
        df['Condition']
          .astype(str)
          .str.strip()
          .str.title()
    )
    unknowns = {'Unknown', 'Unspecified', '', 'None', 'Na', 'Nan'}
    df.loc[df['Condition'].isin(unknowns), 'Condition'] = np.nan
else:
    df['Condition'] = np.nan  # no column → treat as missing

# Drop rows with NaN in key numeric fields
df = df.dropna(subset=['Age_at_Sale', 'Price_num', 'First_Release_Price', 'Storage_num'])

if df.empty:
    raise ValueError("No valid rows available for Pixel Pro regression after filtering. "
                     "Check Release Date / launch price / storage mapping.")

# --------------------------------------------------------
# 7) ONE-HOT ENCODE CONDITION (IF WE HAVE ANY)
# --------------------------------------------------------
has_any_condition = df['Condition'].notna().any()

if has_any_condition:
    enc = OneHotEncoder(drop=None, sparse_output=False, handle_unknown='ignore')
    cond_mat = enc.fit_transform(df[['Condition']])
    cond_cols = enc.get_feature_names_out(['Condition'])
    cond_df = pd.DataFrame(cond_mat, columns=cond_cols, index=df.index)
else:
    enc = None
    cond_cols = []
    cond_df = pd.DataFrame(index=df.index)

# Numeric features
X_num = df[['Age_at_Sale', 'Storage_num', 'Year_of_Sale', 'Month_of_Sale']]
X = pd.concat([X_num, cond_df], axis=1)
y = df['Price_ratio']

good = X.notna().all(axis=1) & y.notna()
X = X.loc[good]
y = y.loc[good]

if X.empty:
    raise ValueError("No rows left after cleaning NaNs in Pixel Pro feature matrix.")

# --------------------------------------------------------
# 8) FIT MODEL
# --------------------------------------------------------
model = lm.LinearRegression()
model.fit(X, y)

print("=== Pixel Pro (Pixel 6 Pro–Pixel 10 Pro XL) Model Fit ===")
print("Samples:", len(y))
print("Intercept:", model.intercept_)
for name, coef in zip(X.columns, model.coef_):
    print(f"{name}: {coef:.6f}")

# --------------------------------------------------------
# 9) PREDICTION HELPER (PIXEL PRO SERIES)
# --------------------------------------------------------
def predict_pixel_pro_price(age_months, storage_gb, year, month, condition, launch_price):
    """
    age_months  : float  (Age_at_Sale in months)
    storage_gb  : int/float (e.g., 128, 256, 512, 1024)
    year        : int   (year of sale, e.g. 2026)
    month       : int   (1–12)
    condition   : str   ('Excellent', 'Very Good', 'Good', 'Fair', etc.)
    launch_price: float (First_Release_Price for that Pixel Pro model + storage)
    """
    cond_str = str(condition).strip().title()

    base = pd.DataFrame({
        'Age_at_Sale':   [age_months],
        'Storage_num':   [float(storage_gb)],
        'Year_of_Sale':  [int(year)],
        'Month_of_Sale': [int(month)],
        'Condition':     [cond_str],
    })

    if enc is not None and len(cond_cols) > 0:
        cond_new = pd.DataFrame(
            enc.transform(base[['Condition']]),
            columns=cond_cols,
            index=base.index
        )
    else:
        cond_new = pd.DataFrame(index=base.index)

    X_new = pd.concat([
        base[['Age_at_Sale', 'Storage_num', 'Year_of_Sale', 'Month_of_Sale']],
        cond_new
    ], axis=1)

    # align with model columns
    X_new = X_new.reindex(columns=X.columns, fill_value=0)

    ratio = model.predict(X_new)[0]
    return ratio * float(launch_price)

# --------------------------------------------------------
# 10) EXAMPLE USAGE (uncomment to test)
# --------------------------------------------------------
# Example: Predict 12-month-old Pixel 9 Pro 256GB in Excellent condition, sold Jan 2027
# lp = pixel_pro_release_price_map['Pixel 9 Pro']['256']
# pred = predict_pixel_pro_price(12, 256, 2027, 1, "Excellent", lp)
# print(f"Predicted Pixel 9 Pro 256GB resale price: ${pred:.2f}")
# Out:
# === Pixel Pro (Pixel 6 Pro–Pixel 10 Pro XL) Model Fit ===
# Samples: 432
# Intercept: -240.10798547366815
# Age_at_Sale: -0.011954
# Storage_num: 0.000111
# Year_of_Sale: 0.118885
# Month_of_Sale: 0.007718
# Condition_Excellent: 0.028251
# Condition_Good: -0.021449
# Condition_Very Good: -0.004887
# Condition_nan: -0.001916

# %%
# === Pixel Pro resale regression (Pixel 6 Pro–Pixel 10 Pro XL)
#     Numeric Condition (Excellent / Very Good / Good only) + RMSE, no year/month ===

import re
import numpy as np
import pandas as pd
import sklearn.linear_model as lm
from sklearn.metrics import root_mean_squared_error

# ------------------------------------------------------------
# 1) LOAD / PREP PIXEL PRO DATA
# ------------------------------------------------------------

# If `data` not already defined, load from CSV
if 'data' not in globals():
    data = pd.read_csv('Pixel_Pro_Combined.csv')  # <-- change filename if needed

data = data.rename(columns=str.strip).copy()
data['Sold Date'] = pd.to_datetime(data['Sold Date'], errors='coerce')

# Numeric sold price
data['Price_num'] = (
    data['Price']
        .astype(str)
        .str.replace('$','', regex=False)
        .str.replace(',','', regex=False)
        .astype(float)
)

# ------------------------------------------------------------
# 2) RELEASE MONTH MAP
# ------------------------------------------------------------
pixel_release_month_map = {
    'Pixel 6 Pro':     "2021-10",
    'Pixel 7 Pro':     "2022-10",
    'Pixel 8 Pro':     "2023-10",
    'Pixel 9 Pro':     "2024-08",
    'Pixel 9 Pro XL':  "2024-08",
    'Pixel 10 Pro':    "2025-10",
    'Pixel 10 Pro XL': "2025-10",
}

# ------------------------------------------------------------
# 3) PIXEL PRO LAUNCH PRICES
# ------------------------------------------------------------
pixel_pro_release_price_map = {
    'Pixel 6 Pro': {'128':899,'256':999,'512':1099},
    'Pixel 7 Pro': {'128':899,'256':999,'512':1099},
    'Pixel 8 Pro': {'128':999,'256':1059,'512':1219,'1024':1399},
    'Pixel 9 Pro': {'128':999,'256':1099,'512':1219,'1024':1449},
    'Pixel 9 Pro XL': {'128':1099,'256':1199,'512':1319,'1024':1549},
    'Pixel 10 Pro': {'128':999,'256':1099,'512':1219},
    'Pixel 10 Pro XL': {'128':1199,'256':1299,'512':1419},
}

# ------------------------------------------------------------
# 4) HELPERS
# ------------------------------------------------------------
def extract_storage(row):
    for col in ['Storage', 'Capacity', 'Memory', 'Storage Capacity']:
        if col in row and pd.notna(row[col]):
            m = re.search(r'(64|128|256|512|1024)', str(row[col]))
            if m: return m.group(1)

    text = f"{row.get('Model','')} {row.get('Title','')}"
    m = re.search(r'\b(64|128|256|512|1024)\b', text)
    return m.group(1) if m else None


def extract_pixel_pro_model_key(row):
    model = str(row.get('Model','')).strip()
    title = str(row.get('Title','')).strip()

    for key in pixel_pro_release_price_map.keys():
        if model.startswith(key): return key
    for key in pixel_pro_release_price_map.keys():
        if key in title: return key
    return None


def map_release_month_pixel(row):
    key = extract_pixel_pro_model_key(row)
    return pixel_release_month_map.get(key, np.nan)


def map_launch_price_pixel(row):
    key = extract_pixel_pro_model_key(row)
    storage = extract_storage(row)
    if key and storage:
        return pixel_pro_release_price_map.get(key, {}).get(storage, np.nan)
    return np.nan

# Apply mappings
data['Release Date'] = pd.to_datetime(data.apply(map_release_month_pixel, axis=1))
data['First_Release_Price'] = data.apply(map_launch_price_pixel, axis=1)

# ------------------------------------------------------------
# 5) AGE AT SALE
# ------------------------------------------------------------
data['Age_at_Sale'] = (data['Sold Date'] - data['Release Date']).dt.days / 30.44

# ------------------------------------------------------------
# 6) BUILD REGRESSION DF
# ------------------------------------------------------------
mask = (
    data['Age_at_Sale'].notna() &
    data['Price_num'].notna() &
    data['First_Release_Price'].notna() &
    (data['First_Release_Price'] > 0)
)

df = data.loc[mask].copy()
df['Price_ratio'] = df['Price_num'] / df['First_Release_Price']
df['Storage_num'] = df.apply(lambda r: float(extract_storage(r) or np.nan), axis=1)

# Condition cleanup
df['Condition'] = df['Condition'].astype(str).str.strip().str.title()
unknowns = {'Unknown','Unspecified','','None','Na','Nan'}
df.loc[df['Condition'].isin(unknowns), 'Condition'] = np.nan

# ------------------------------------------------------------
# ONLY allow Excellent, Very Good, Good
# ------------------------------------------------------------
valid_conditions = {'Excellent','Very Good','Good'}
df.loc[~df['Condition'].isin(valid_conditions), 'Condition'] = np.nan

df = df.dropna(subset=['Condition','Age_at_Sale','Price_ratio','Storage_num'])

# Numeric condition mapping (ONLY 3 values)
cond_map = {
    'Excellent': 2,
    'Very Good': 1,
    'Good': 0,
}
df['Condition'] = df['Condition'].map(cond_map)

# ------------------------------------------------------------
# 7) FEATURES
# ------------------------------------------------------------
X = df[['Age_at_Sale','Storage_num','Condition']].astype(float)
y = df['Price_ratio'].astype(float)

X = X.loc[X.notna().all(axis=1)]
y = y.loc[X.index]

# ------------------------------------------------------------
# 8) FIT + RMSE
# ------------------------------------------------------------
model = lm.LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)
rmse = root_mean_squared_error(y, y_pred)

print("=== Pixel Pro Model Fit (3-condition numeric, no year/month) ===")
print("Samples:", len(y))
print("RMSE:", rmse)
print("Intercept:", model.intercept_)
for name, coef in zip(X.columns, model.coef_):
    print(f"{name}: {coef:.6f}")

# ------------------------------------------------------------
# 9) PREDICTOR
# ------------------------------------------------------------
def predict_pixel_pro_price(age_months, storage_gb, condition, launch_price):
    cond_val = cond_map.get(str(condition).strip().title())
    if cond_val is None:
        raise ValueError(f"Condition must be one of: {list(cond_map.keys())}")

    base = pd.DataFrame({
        'Age_at_Sale': [age_months],
        'Storage_num': [float(storage_gb)],
        'Condition':   [cond_val],
    })

    X_new = base[X.columns]
    ratio = model.predict(X_new)[0]
    return ratio * float(launch_price)

# Example usage:
# lp = pixel_pro_release_price_map['Pixel 9 Pro']['256']
# pred = predict_pixel_pro_price(12, 256, "Excellent", lp)
# print(pred)
# Out:
# === Pixel Pro Model Fit (3-condition numeric, no year/month) ===
# Samples: 337
# RMSE: 0.051574711607796635
# Intercept: 0.6705880018400051
# Age_at_Sale: -0.011633
# Storage_num: 0.000104
# Condition: 0.024230
