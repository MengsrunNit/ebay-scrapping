# %%
import re
import pandas as pd

# Load data
iphone12pro = pd.read_csv('iphone_12_pro_only.csv')

# Step 1: Remove rows with '|' (multiple model options)
iphone12pro = iphone12pro[~iphone12pro['Title'].str.contains(r'\|', regex=True, na=False)]

# Step 2: Remove titles that list multiple models like "12 - 12 Pro" or "11 / 12 / 13"
pattern_multi = r'\b(?:iPhone\s*)?(?:[0-9]+)\b\s*[-/|]\s*\b(?:iPhone\s*)?(?:[0-9]+)(?:\s*(?:Pro|Pro\s*Max|Mini))?\b'
iphone12pro = iphone12pro[~iphone12pro['Title'].str.contains(pattern_multi, flags=re.IGNORECASE, na=False)]

# Step 3: Keep only “iPhone 12 Pro” — not 12, 12 Pro Max, or 12 Mini
iphone12pro = iphone12pro[
    iphone12pro['Title'].str.contains(r'\biPhone\s*12\s*Pro\b', flags=re.IGNORECASE, na=False)
    & ~iphone12pro['Title'].str.contains(r'\bPro\s*Max\b', flags=re.IGNORECASE, na=False)
    & ~iphone12pro['Title'].str.contains(r'\bMini\b', flags=re.IGNORECASE, na=False)
]

# Preview
iphone12pro
# Out:
#      Page                                              Title    Price  \
# 1       1          Apple iPhone 12 Pro 256GB Unlocked - Good  $289.99
# 3       1     Apple iPhone 12 Pro 256GB Unlocked - Excellent  $295.95
# 4       1  Apple iPhone 12 Pro 128GB Factory Unlocked AT&...  $261.95
# 5       1  Apple iPhone 12 Pro 256GB Unlocked AT&T T-Mobi...  $279.95
# 6       1  Apple iPhone 12 Pro 128GB Unlocked AT&T T-Mobi...  $275.95
# ..    ...                                                ...      ...
# 127     3  Apple iPhone 12 Pro 256GB Unlocked Excellent C...  $339.99
# 128     3  Apple iPhone 12 Pro - 6.1" - 128GB - Fully Unl...  $321.00
# 129     3  Apple iPhone 12 Pro 256GB A2341 Unlocked AT&T ...  $281.99
# 130     3  Apple iPhone 12 Pro - 256 GB - Graphite - Unlo...  $277.00
# 131     3  Apple iPhone 12 Pro A2341 Unlocked 256GB Graph...  $304.99
#
#       Sold Date                                   Link  \
# 1    2025-10-22  https://www.ebay.com/itm/256426051256
# ...

# %%
import re
import pandas as pd

# Load data
iphone13pro = pd.read_csv('iphone_13_pro_only.csv')

# Step 1: Remove rows with '|' (multiple model options)
iphone13pro = iphone13pro[~iphone13pro['Title'].str.contains(r'\|', regex=True, na=False)]

# Step 2: Remove titles that list multiple models like "13 - 13 Pro" or "12 / 13 / 14"
pattern_multi = r'\b(?:iPhone\s*)?(?:[0-9]+)\b\s*[-/|]\s*\b(?:iPhone\s*)?(?:[0-9]+)(?:\s*(?:Pro|Pro\s*Max|Mini))?\b'
iphone13pro = iphone13pro[~iphone13pro['Title'].str.contains(pattern_multi, flags=re.IGNORECASE, na=False)]

# Step 3: Keep only “iPhone 13 Pro” — not 13, 13 Mini, or 13 Pro Max
iphone13pro = iphone13pro[
    iphone13pro['Title'].str.contains(r'\biPhone\s*13\s*Pro\b', flags=re.IGNORECASE, na=False)
    & ~iphone13pro['Title'].str.contains(r'\bPro\s*Max\b', flags=re.IGNORECASE, na=False)
    & ~iphone13pro['Title'].str.contains(r'\bMini\b', flags=re.IGNORECASE, na=False)
]

# Preview
iphone13pro
# Out:
#      Page                                              Title    Price  \
# 0       1  Apple iPhone 13 Pro - 128 GB - Sierra Blue - U...  $388.55
# 1       1  Apple iPhone 13 Pro Green 128GB Good - Refurbi...  $358.99
# 2       1    Apple iPhone 13 Pro 512GB Fully Unlocked - Good  $382.99
# 3       1  Apple iPhone 13 Pro Silver 128GB Excellent - R...  $398.99
# 4       1  Apple iPhone 13 Pro 128GB Unlocked Very Good C...  $379.99
# ..    ...                                                ...      ...
# 150     3  iPhone 13 Pro 1TB Green Unlocked Straight Talk...  $480.00
# 151     3  Apple iPhone 13 Pro Alpine Green 256GB Unlocke...  $394.99
# 152     3  Apple iPhone 13 Pro A2483 256GB Unlocked Excel...  $437.98
# 153     3  Apple iPhone 13 Pro 1TB Alpine Green Unlocked ...  $552.69
# 154     3  Apple Iphone 13 Pro A2483 256GB Smartphone Sil...  $399.00
#
#       Sold Date                                   Link  \
# 0    2025-10-22  https://www.ebay.com/itm/335906202569
# ...

# %%
import re
import pandas as pd

# Load data
iphone14pro = pd.read_csv('iphone_14_pro_only.csv')

# Step 1: Remove rows with '|' (multiple model options)
iphone14pro = iphone14pro[~iphone14pro['Title'].str.contains(r'\|', regex=True, na=False)]

# Step 2: Remove titles that list multiple models like "14 - 14 Pro" or "13 / 14 / 15"
pattern_multi = r'\b(?:iPhone\s*)?(?:[0-9]+)\b\s*[-/|]\s*\b(?:iPhone\s*)?(?:[0-9]+)(?:\s*(?:Pro|Pro\s*Max|Plus|Mini))?\b'
iphone14pro = iphone14pro[~iphone14pro['Title'].str.contains(pattern_multi, flags=re.IGNORECASE, na=False)]

# Step 3: Keep only “iPhone 14 Pro” — not 14, 14 Plus, or 14 Pro Max
iphone14pro = iphone14pro[
    iphone14pro['Title'].str.contains(r'\biPhone\s*14\s*Pro\b', flags=re.IGNORECASE, na=False)
    & ~iphone14pro['Title'].str.contains(r'\bPro\s*Max\b', flags=re.IGNORECASE, na=False)
    & ~iphone14pro['Title'].str.contains(r'\bPlus\b', flags=re.IGNORECASE, na=False)
]

# Preview
iphone14pro
# Out:
#     Page                                              Title    Price  \
# 0      1  Apple iPhone 14 Pro Silver 256GB Excellent - R...  $494.99
# 1      1  Apple iPhone 14 Pro A2650 (Unlocked) 256GB Spa...  $448.99
# 2      1  Apple iPhone 14 Pro A2650 128GB Network Unlock...  $409.99
# 3      1  Apple iPhone 14 Pro 256GB Unlocked AT&T T-Mobi...  $447.95
# 4      1  Apple iPhone 14 Pro A2650 Unlocked 128GB Silve...  $484.99
# ..   ...                                                ...      ...
# 88     3  Apple iPhone 14 Pro - 128GB - Unlocked- Excell...  $525.00
# 89     3  Apple iPhone 14 Pro 128GB 256GB 512GB 1TB Unlo...  $534.83
# 90     3  iPhone 14 Pro (512GB, 6GB) 6.1", iOS 17, 5G / ...  $531.99
# 91     3  Apple iPhone 14 Pro - 128GB/256GB/512GB/1TB, A...  $449.00
# 92     3  iPhone 14 Pro 128 GB Purple Unlocked (ALL CARR...  $424.99
#
#      Sold Date                                   Link  \
# 0   2025-10-22  https://www.ebay.com/itm/127324783614
# ...

# %%
import re
import pandas as pd

# Load data
iphone15pro = pd.read_csv('iphone_15_pro_only.csv')

# Step 1: Remove rows with '|' (multiple model options)
iphone15pro = iphone15pro[~iphone15pro['Title'].str.contains(r'\|', regex=True, na=False)]

# Step 2: Remove titles that list multiple models like "15 - 15 Pro" or "14 / 15 / 16"
pattern_multi = r'\b(?:iPhone\s*)?(?:[0-9]+)\b\s*[-/|]\s*\b(?:iPhone\s*)?(?:[0-9]+)(?:\s*(?:Pro|Pro\s*Max|Plus|Mini))?\b'
iphone15pro = iphone15pro[~iphone15pro['Title'].str.contains(pattern_multi, flags=re.IGNORECASE, na=False)]

# Step 3: Keep only “iPhone 15 Pro” — not 15, 15 Plus, or 15 Pro Max
iphone15pro = iphone15pro[
    iphone15pro['Title'].str.contains(r'\biPhone\s*15\s*Pro\b', flags=re.IGNORECASE, na=False)
    & ~iphone15pro['Title'].str.contains(r'\bPro\s*Max\b', flags=re.IGNORECASE, na=False)
    & ~iphone15pro['Title'].str.contains(r'\bPlus\b', flags=re.IGNORECASE, na=False)
]

# Preview
iphone15pro
# Out:
#      Page                                              Title    Price  \
# 0       1  Apple iPhone 15 Pro 1TB Unlocked AT&T T-Mobile...  $696.95
# 1       1  Apple iPhone 15 Pro 1TB Unlocked AT&T T-Mobile...  $654.95
# 2       1  Apple iPhone 15 Pro A2848 256GB Unlocked Excel...  $590.99
# 3       1  Apple iPhone 15 Pro 256GB Unlocked AT&T T-Mobi...  $577.95
# 4       1  Apple iPhone 15 Pro 128GB Unlocked AT&T T-Mobi...  $548.95
# ..    ...                                                ...      ...
# 152     2  Apple iPhone 15 Pro - Unlocked - 256GB - White...  $642.00
# 153     2  Apple iPhone 15 Pro 1TB Unlocked Excellent Con...  $819.99
# 154     2  Apple iPhone 15 Pro - 512GB - Natural Titanium...  $729.00
# 155     2  Apple iPhone 15 Pro - 1TB Blue *UNLOCKED* [eSI...  $789.99
# 156     2  Apple iPhone 15 Pro 512GB Unlocked 6.1" (Black...  $674.56
#
#       Sold Date                                   Link  \
# 0    2025-10-22  https://www.ebay.com/itm/305315521310
# ...

# %%
import re
import pandas as pd

# Load data
iphone16pro = pd.read_csv('iphone_16_pro_only.csv')

# Step 1: Remove rows with '|' (multiple model options)
iphone16pro = iphone16pro[~iphone16pro['Title'].str.contains(r'\|', regex=True, na=False)]

# Step 2: Remove titles that list multiple models like "16 - 16 Pro" or "15 / 16 / 17"
pattern_multi = r'\b(?:iPhone\s*)?(?:[0-9]+)\b\s*[-/|]\s*\b(?:iPhone\s*)?(?:[0-9]+)(?:\s*(?:Pro|Pro\s*Max|Plus|Mini))?\b'
iphone16pro = iphone16pro[~iphone16pro['Title'].str.contains(pattern_multi, flags=re.IGNORECASE, na=False)]

# Step 3: Keep only “iPhone 16 Pro” — not 16, 16 Plus, or 16 Pro Max
iphone16pro = iphone16pro[
    iphone16pro['Title'].str.contains(r'\biPhone\s*16\s*Pro\b', flags=re.IGNORECASE, na=False)
    & ~iphone16pro['Title'].str.contains(r'\bPro\s*Max\b', flags=re.IGNORECASE, na=False)
    & ~iphone16pro['Title'].str.contains(r'\bPlus\b', flags=re.IGNORECASE, na=False)
]

# Preview
iphone16pro
# Out:
#      Page                                              Title      Price  \
# 0       1  Apple iPhone 16 Pro 1TB Unlocked AT&T T-Mobile...    $929.95
# 1       1  Apple iPhone 16 Pro 128GB Unlocked AT&T T-Mobi...    $723.95
# 2       1  Apple iPhone 16 Pro 256GB Unlocked AT&T T-Mobi...    $755.95
# 3       1  Apple iPhone 16 Pro 256GB Unlocked Excellent C...    $767.99
# 4       1  Apple iPhone 16 Pro 128GB Unlocked Very Good C...    $676.99
# ..    ...                                                ...        ...
# 103     3  Apple iPhone 16 Pro A3083 Unlocked 128GB Deser...    $734.99
# 104     3  Apple iPhone 16 Pro - 128 GB - White Titanium ...    $789.95
# 105     3  Apple iPhone 16 Pro - A3083 - Unlocked - Excel...    $749.99
# 106     3  Apple iPhone 16 Pro 256GB UnlockedCondition - ...  $1,478.00
# 107     3  Apple iPhone 16 Pro 512GB (Unlocked) eSim Only...    $959.94
#
#       Sold Date                                   Link  \
# ...

# %%
import re
import pandas as pd

# Load data
iphone17pro = pd.read_csv('iphone_17_pro_only.csv')

# Step 1: Remove rows with '|' (multiple model options)
iphone17pro = iphone17pro[~iphone17pro['Title'].str.contains(r'\|', regex=True, na=False)]

# Step 2: Remove titles that list multiple models like "17 - 17 Pro" or "16 / 17 / 18"
pattern_multi = r'\b(?:iPhone\s*)?(?:[0-9]+)\b\s*[-/|]\s*\b(?:iPhone\s*)?(?:[0-9]+)(?:\s*(?:Pro|Pro\s*Max|Plus|Mini))?\b'
iphone17pro = iphone17pro[~iphone17pro['Title'].str.contains(pattern_multi, flags=re.IGNORECASE, na=False)]

# Step 3: Keep only “iPhone 17 Pro” — not 17, 17 Plus, or 17 Pro Max
iphone17pro = iphone17pro[
    iphone17pro['Title'].str.contains(r'\biPhone\s*17\s*Pro\b', flags=re.IGNORECASE, na=False)
    & ~iphone17pro['Title'].str.contains(r'\bPro\s*Max\b', flags=re.IGNORECASE, na=False)
    & ~iphone17pro['Title'].str.contains(r'\bPlus\b', flags=re.IGNORECASE, na=False)
]

# Preview
iphone17pro
# Out:
#    Page                                              Title      Price  \
# 0     1  Apple iPhone 17 Pro - Unlocked - 256GB - Silve...  $1,059.00
# 1     1  Apple iPhone 17 Pro - 512 GB - Silver (Unlocke...  $1,199.95
# 2     1  Apple iPhone 17 Pro 256GB Unlocked eSim Only C...  $1,284.95
#
#     Sold Date                                   Link  \
# 0  2025-10-21  https://www.ebay.com/itm/286890822891
# 1  2025-10-18  https://www.ebay.com/itm/306554628532
# 2  2025-10-05  https://www.ebay.com/itm/406254631675
#
#                                           Image Link Storage  Condition  \
# 0  https://i.ebayimg.com/images/g/HcUAAeSw9sdo-AK...  256 GB  Excellent
# 1  https://i.ebayimg.com/images/g/yzEAAeSw7EFo8qf...  512 GB    Unknown
# 2  https://i.ebayimg.com/images/g/r1wAAeSwxUxo3N1...  256 GB  Excellent
#
#    PartsOnly          Model  iPhone_17_Pro
# 0      False  iPhone 17 Pro           True
# 1      False  iPhone 17 Pro           True
# 2      False  iPhone 17 Pro           True

# %%
# Combine all cleaned DataFrames
iphone_pro_base = pd.concat([iphone12pro, iphone13pro, iphone14pro, iphone15pro, iphone16pro, iphone17pro], ignore_index=True)

# Save to a new CSV
iphone_pro_base.to_csv('iphone_pro.csv', index=False)

# %%
data = pd.read_csv('iPhone_pro.csv')
data['Sold Date'] = pd.to_datetime(data['Sold Date'])
data['year']= data['Sold Date'].dt.year
data['Month'] = data['Sold Date'].dt.month
data['Price_num'] = data['Price'].str.replace('$', '').str.replace(',', '').astype(float)
data['Release Date'] = data['Model'].replace({
    "iPhone 12 Pro": "2020-10",
    "iPhone 13 Pro": "2021-09",
    "iPhone 14 Pro": "2022-09",
    "iPhone 15 Pro": "2023-09",
    "iPhone 16 Pro": "2024-09",
    "iPhone 17 Pro": "2025-09"
})

# %%
#make it month
data["Age_at_Sale"] = (data['Sold Date'] - pd.to_datetime(data['Release Date'])).dt.days / 30.44  # Approximate months
data["Age_at_Sale"] = data["Age_at_Sale"].round(2)
data
# Out:
#      Page                                              Title      Price  \
# 0       1          Apple iPhone 12 Pro 256GB Unlocked - Good    $289.99
# 1       1     Apple iPhone 12 Pro 256GB Unlocked - Excellent    $295.95
# 2       1  Apple iPhone 12 Pro 128GB Factory Unlocked AT&...    $261.95
# 3       1  Apple iPhone 12 Pro 256GB Unlocked AT&T T-Mobi...    $279.95
# 4       1  Apple iPhone 12 Pro 128GB Unlocked AT&T T-Mobi...    $275.95
# ..    ...                                                ...        ...
# 630     3  Apple iPhone 16 Pro 256GB UnlockedCondition - ...  $1,478.00
# 631     3  Apple iPhone 16 Pro 512GB (Unlocked) eSim Only...    $959.94
# 632     1  Apple iPhone 17 Pro - Unlocked - 256GB - Silve...  $1,059.00
# 633     1  Apple iPhone 17 Pro - 512 GB - Silver (Unlocke...  $1,199.95
# 634     1  Apple iPhone 17 Pro 256GB Unlocked eSim Only C...  $1,284.95
#
#      Sold Date                                   Link  \
# ...

# %%
# Map first release price for iPhone Pro models (12–17) by storage capacity
import re
import numpy as np
import pandas as pd

# Prices (U.S. launch prices) for iPhone Pro models by storage
# Keys are strings like "12 Pro", "13 Pro", ...
release_price_map = {
    # iPhone 12 Pro: 128GB $999, 256GB $1099, 512GB $1299 :contentReference[oaicite:0]{index=0}
    '12 Pro': { '128': 999.0, '256': 1099.0, '512': 1299.0 },

    # iPhone 13 Pro: same launch structure as 12 Pro (Apple kept Pro pricing tiers) :contentReference[oaicite:1]{index=1}
    '13 Pro': { '128': 999.0, '256': 1099.0, '512': 1299.0 },

    # iPhone 14 Pro: same base launch prices as 13 Pro :contentReference[oaicite:2]{index=2}
    '14 Pro': { '128': 999.0, '256': 1099.0, '512': 1299.0 },

    # iPhone 15 Pro: same launch prices (128/256/512) :contentReference[oaicite:3]{index=3}
    '15 Pro': { '128': 999.0, '256': 1099.0, '512': 1299.0 },

    # iPhone 16 Pro: launched at same tiers before being discontinued :contentReference[oaicite:4]{index=4}
    '16 Pro': { '128': 999.0, '256': 1099.0, '512': 1299.0 },

    # iPhone 17 Pro: base storage doubled to 256GB at $1,099 :contentReference[oaicite:5]{index=5}
    '17 Pro': { '256': 1099.0, '512': 1299.0 },
}

# Function to extract storage from common columns or fallback to Title parsing
def extract_storage_from_row(row):
    # Try common explicit columns first (if they exist)
    for col in ['Storage', 'Capacity', 'Memory', 'Storage Capacity']:
        if col in row.index and pd.notna(row[col]):
            s = str(row[col])
            m = re.search(r'(64|128|256|512)', s)
            if m:
                return m.group(1)

    # Fallback: parse Title (and optionally Model)
    title = str(row.get('Title', ''))
    m = re.search(r'\b(64|128|256|512)\s*(?:GB|G|gb)?\b', title, flags=re.IGNORECASE)
    if m:
        return m.group(1)

    # Try compact forms like '64GB' without space
    m = re.search(r'(64|128|256|512)GB', title, flags=re.IGNORECASE)
    if m:
        return m.group(1)

    return None

# Helper to get model key (e.g., '12 Pro', '15 Pro') from Model or Title fields
def extract_model_key(row):
    # Check Model column first, then Title
    text = str(row.get('Model', '') or row.get('Title', ''))

    # Match patterns like "iPhone 14 Pro", "iphone13 pro", etc.
    m = re.search(r'iphone\s*([0-9]{1,2})\s*pro\b', text, flags=re.IGNORECASE)
    if m:
        num = m.group(1).strip()
        return f'{num} Pro'  # e.g. "12 Pro"
    return None

# Mapper that assigns the release price if we have a mapping for that model+storage
def map_first_release_price(row):
    model_key = extract_model_key(row)   # e.g. "13 Pro"
    if not model_key:
        return np.nan

    if model_key not in release_price_map:
        return np.nan

    storage = extract_storage_from_row(row)
    if storage and storage in release_price_map[model_key]:
        return release_price_map[model_key][storage]

    return np.nan

# Apply mapping to the DataFrame named `data` (already created earlier in the notebook)
# If `data` is not in memory, re-load from the CSV generated earlier: 'iPhone_base.csv'
if 'data' not in globals():
    try:
        data = pd.read_csv('iPhone_base.csv')
        data['Sold Date'] = pd.to_datetime(data['Sold Date'], errors='coerce')
    except FileNotFoundError:
        raise FileNotFoundError('iPhone_base.csv not found; run earlier cells to produce `data`')

# Create/overwrite the column
data['First_Release_Price'] = data.apply(map_first_release_price, axis=1)

# Quick checks: report filled counts per Pro model
for model_key, mapping in release_price_map.items():
    model_label = f'iPhone {model_key}'  # e.g. "iPhone 13 Pro"
    mask = data['Model'].str.contains(model_label, case=False, na=False)
    total = data[mask].shape[0]
    filled = data[mask & data['First_Release_Price'].notna()].shape[0]
    print(f'{model_label}: filled {filled} / {total}')

# Show sample rows where price was set
display(data[data['First_Release_Price'].notna()].head())

# Optionally save an updated CSV
# data.to_csv('iPhone_Pro_with_release_price.csv', index=False)
# Out:
# iPhone 12 Pro: filled 127 / 130
# iPhone 13 Pro: filled 133 / 148
# iPhone 14 Pro: filled 82 / 90
# iPhone 15 Pro: filled 137 / 156
# iPhone 16 Pro: filled 91 / 108
# iPhone 17 Pro: filled 3 / 3
#    Page                                              Title    Price  \
# 0     1          Apple iPhone 12 Pro 256GB Unlocked - Good  $289.99
# 1     1     Apple iPhone 12 Pro 256GB Unlocked - Excellent  $295.95
# 2     1  Apple iPhone 12 Pro 128GB Factory Unlocked AT&...  $261.95
# 3     1  Apple iPhone 12 Pro 256GB Unlocked AT&T T-Mobi...  $279.95
# 4     1  Apple iPhone 12 Pro 128GB Unlocked AT&T T-Mobi...  $275.95
#
#    Sold Date                                   Link  \
# 0 2025-10-22  https://www.ebay.com/itm/256426051256
# 1 2025-10-22  https://www.ebay.com/itm/403448551891
# 2 2025-10-22  https://www.ebay.com/itm/304222884177
# 3 2025-10-22  https://www.ebay.com/itm/304104247802
# 4 2025-10-22  https://www.ebay.com/itm/294304467850
#
# ...

# %%
from matplotlib import pyplot as plt
import numpy as np

# Remove any accidental leading/trailing spaces in column names
data.rename(columns=str.strip, inplace=True)

# Use clean columns
x = data['Age_at_Sale']   # months
y = data['Price_num']

# Drop NaNs/infs before fitting
m = np.isfinite(x) & np.isfinite(y)
x = x[m].to_numpy()
y = y[m].to_numpy()

# Fit and build polynomial (5th-degree)
coeffs = np.polyfit(x, y, 5)
poly_eq = np.poly1d(coeffs)

# Smooth curve for the fit
x_line = np.linspace(x.min(), x.max(), 200)
y_line = poly_eq(x_line)

# Plot scatter + fitted curve
plt.scatter(x, y, s=15, alpha=0.6, label='Data')
plt.plot(x_line, y_line, linewidth=2, label='5th-degree fit')

plt.xlabel('Age at Sale (Months)')
plt.ylabel('Price ($)')
plt.title('iPhone Price Depreciation Over Time')
plt.legend()
plt.tight_layout()
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

# Clean column names
data.rename(columns=str.strip, inplace=True)

# Extract data
x = data['Age_at_Sale']   # months
y = data['Price_num']

# Clean NaN/inf
m = np.isfinite(x) & np.isfinite(y)
x = x[m].to_numpy()
y = y[m].to_numpy()

# ---- Value retention (%) ----
original_price = y.max()
retention = (y / original_price) * 100

# ---- 3rd-degree polynomial fit for value retention ----
coeffs = np.polyfit(x, retention, 3)
poly_ret = np.poly1d(coeffs)

# Smooth line
x_line = np.linspace(x.min(), x.max(), 200)
y_line_ret = poly_ret(x_line)

# ---- Plot ----
plt.figure(figsize=(8,5))
plt.scatter(x, retention, s=15, alpha=0.6, label='iPhone Pro Model Data')
plt.plot(x_line, y_line_ret, linewidth=2, label='3rd-degree retention fit')

plt.xlabel('Age at Sale (Months)')
plt.ylabel('Value Retained (%)')
plt.title('iPhone Pro Model Value Retention Over Time')
plt.ylim(0, 110)
plt.legend()
plt.tight_layout()

import os
# Save figure
os.makedirs('output', exist_ok=True)
plt.savefig('output/pixel_value_retention_polynomial_fit.png', dpi=300)

plt.show()

# %%
# === iPhone Pro resale regression (with explicit Condition_Excellent) ===
import re
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder

# ------------------------------------------------------------
# 0) START: assume `data` already exists (DataFrame with at least the columns below)
# Required columns used here:
#   ['Sold Date', 'Release Date' (optional if Age_at_Sale already present),
#    'Age_at_Sale' (months) OR ('Sold Date' & 'Release Date'),
#    'Price_num', 'First_Release_Price', 'Storage' (or Title), 'Condition',
#    'Model' or 'Title' with "Pro" in the name]
# ------------------------------------------------------------

# Basic hygiene
data = data.rename(columns=str.strip).copy()
data['Sold Date'] = pd.to_datetime(data['Sold Date'], errors='coerce')

# -----------------------------
# 0.5) Filter to Pro models
# -----------------------------
if 'Model' in data.columns:
    pro_mask = data['Model'].astype(str).str.contains(r'\bPro\b', case=False, na=False)
elif 'Title' in data.columns:
    pro_mask = data['Title'].astype(str).str.contains(r'\bPro\b', case=False, na=False)
else:
    raise ValueError("Need a 'Model' or 'Title' column to filter Pro devices.")

data = data.loc[pro_mask].copy()

# If Age_at_Sale (months) not present, compute it
if 'Age_at_Sale' not in data.columns:
    data['Release Date'] = pd.to_datetime(data['Release Date'], errors='coerce')
    data['Age_at_Sale'] = (data['Sold Date'] - data['Release Date']).dt.days / 30.44

# Mask of valid rows
mask = (
    data['Age_at_Sale'].notna() &
    data['Price_num'].notna() &
    data['First_Release_Price'].notna() &
    (data['First_Release_Price'] > 0) &
    data['Sold Date'].notna()
)

df = data.loc[mask].copy()

# Target: normalized resale price (ratio of launch price)
df['Price_ratio'] = (
    pd.to_numeric(df['Price_num'], errors='coerce') /
    pd.to_numeric(df['First_Release_Price'], errors='coerce')
)

# Storage: numeric GB. Prefer 'Storage', fallback to 'Title'
if 'Storage' in df.columns:
    storage_src = df['Storage'].astype(str)
else:
    storage_src = df.get('Title', pd.Series(index=df.index, dtype=str)).astype(str)

df['Storage_num'] = storage_src.str.extract(r'(\d+)', expand=False).astype(float)

# Year / Month of sale
df['Year_of_Sale']  = df['Sold Date'].dt.year
df['Month_of_Sale'] = df['Sold Date'].dt.month

# Condition cleanup: title-case, drop unknown-like
df['Condition'] = (
    df.get('Condition', pd.Series(index=df.index, dtype=object))
      .astype(str)
      .str.strip()
      .str.title()
)
unknown_like = {'Unknown', 'Unspecified', 'Na', 'Nan', 'None', ''}
df.loc[df['Condition'].isin(unknown_like), 'Condition'] = np.nan
df = df.dropna(subset=['Condition'])

# One-hot encode Condition with ALL categories (includes 'Condition_Excellent' explicitly)
enc = OneHotEncoder(drop=None, sparse_output=False, handle_unknown='ignore')
cond_mat  = enc.fit_transform(df[['Condition']])
cond_cols = enc.get_feature_names_out(['Condition'])
cond_df   = pd.DataFrame(cond_mat, columns=cond_cols, index=df.index)

# Assemble feature matrix
X_num = df[['Age_at_Sale', 'Storage_num', 'Year_of_Sale', 'Month_of_Sale']].apply(
    pd.to_numeric, errors='coerce'
)
X = pd.concat([X_num, cond_df], axis=1)
y = pd.to_numeric(df['Price_ratio'], errors='coerce')

# Final clean for safety
good = X.notna().all(axis=1) & y.notna()
X = X.loc[good]
y = y.loc[good]

# Fit model (Pro-only)
model = LinearRegression()
model.fit(X, y)

# Report
print("=== Pro Model Fit ===")
print("Samples used:", len(y))
print("Intercept:", model.intercept_)
print("Coefficients:")
for name, coef in zip(X.columns, model.coef_):
    print(f"  {name}: {coef:.6f}")

# ------------------------------------------------------------
# Helper: predict absolute resale price in dollars (Pro-only model)
# age_months: float
# storage_gb: int/float (e.g., 128, 256)
# year, month: ints
# condition: string like 'Excellent', 'Very Good', 'Good', 'Fair', 'Poor', etc.
# launch_price: float (First_Release_Price for that Pro model+storage)
# ------------------------------------------------------------
def predict_price_pro(age_months, storage_gb, year, month, condition, launch_price):
    # build a one-row frame
    base = pd.DataFrame({
        'Age_at_Sale': [age_months],
        'Storage_num': [storage_gb],
        'Year_of_Sale': [year],
        'Month_of_Sale': [month],
        'Condition': [str(condition).strip().title()]
    })

    # encode condition using fitted encoder
    cond_new = pd.DataFrame(
        enc.transform(base[['Condition']]),
        columns=cond_cols,
        index=base.index
    )

    X_new = pd.concat(
        [base[['Age_at_Sale', 'Storage_num', 'Year_of_Sale', 'Month_of_Sale']], cond_new],
        axis=1
    )

    # align columns with training matrix (missing -> 0)
    X_new = X_new.reindex(columns=X.columns, fill_value=0)

    ratio = float(model.predict(X_new))
    return ratio * float(launch_price)

# Example usage (for a Pro device):
# predicted_usd = predict_price_pro(
#     age_months=18,
#     storage_gb=256,
#     year=2024,
#     month=6,
#     condition='Excellent',
#     launch_price=999
# )
# print(f"Predicted Pro resale: ${predicted_usd:.2f}")
# Out:
# === Pro Model Fit ===
# Samples used: 485
# Intercept: -122.99955638040322
# Coefficients:
#   Age_at_Sale: -0.009105
#   Storage_num: -0.000122
#   Year_of_Sale: 0.061148
#   Month_of_Sale: 0.001370
#   Condition_Excellent: 0.023666
#   Condition_Good: -0.023880
#   Condition_Very Good: 0.000215
